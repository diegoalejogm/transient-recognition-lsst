# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
import pandas as pd

# %config InlineBackend.rc = {}
# %matplotlib inline

# %%
data_path = './data/PESSTO/'

# Catalogues
photometry_path = data_path + 'Multi-epoch Photometry Catalogue/'
transient_path = data_path + 'Transient Catalogue/'
# Data
imaging_path = data_path + 'Imaging Data/'
spectral_path = data_path + 'Spectral Data/'

# %% [markdown]
# ## Transient Catalogue Exploration

# %%
trans_cat_filename = 'ADP.2017-08-24T09:39:15.903.fits'

hdu_list = fits.open(transient_path + trans_cat_filename)
hdu_list.info()
# Out:
# Filename: ./data/PESSTO/Transient Catalogue/ADP.2017-08-24T09:39:15.903.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      23   ()
#   1  PHASE3CATALOG    1 BinTableHDU    227   1035R x 30C   [50A, 50A, E, E, 20A, I, 20A, I, J, E, 20A, I, I, J, E, 10A, I, I, 50A, E, E, E, E, 10A, E, 10A, E, E, 50A, 200A]

# %%
# Display PRIMARY HDU Info
hdu_list[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'ESO     '           / European Southern Observatory
# DATE    = '2017-08-14T13:45:06' / Date the file was written
# TELESCOP= 'ESO-NTT '           / ESO Telescope designation
# INSTRUME= 'EFOSC   '           / Instrument name
# RADECSYS= 'FK5     '           / Coordinate reference frame
# MJD-OBS =                55930 / Start of observations (days)
# MJD-END =                57509 / End of observations (days)
# PROG_ID = 'MULTI   '           / ESO programme identification
# PROGID1 = '188.D-3003'         / ESO programme identification
# PROGID2 = '191.D-0935'         / ESO programme identification
# OBSTECH = 'SPECTRUM'           / Technique of observation
# PROCSOFT= 'ntt_2.2.8'          / Data reduction software/system with version no.
# PRODCATG= 'SCIENCE.CATALOG'    / Data product category
# REFERENC= '2015A&A...579A..40S' / Bibcode reference
# CHECKSUM= '7VAAAT420TA97T39'   / HDU checksum updated 2017-08-25T13:32:13
# DATASUM = '0       '           / data unit checksum updated 2017-08-14T13:45:06
# ARCFILE = 'ADP.2017-08-24T09:39:15.903.fits' / Archive File Name
# ORIGFILE= 'PESSTO_TRAN_CAT.fits' / Original File Name
# P3ORIG  = 'EDP     '           / ESO external data product

# %%
# Has PRIMARY HDU got any data?
print(hdu_list[0].data is not None)
# Out:
# False

# %%
# Display BINTABLE HDU Info
hdu_list[1].header
# Out:
# XTENSION= 'BINTABLE'           / FITS Extension first keyword
# BITPIX  =                    8 / Number of bits per data pixel
# NAXIS   =                    2 / Number of data axes
# NAXIS1  =                  554 / width of table in bytes
# NAXIS2  =                 1035 / number of rows in table
# PCOUNT  =                    0 / Parameter count
# GCOUNT  =                    1 / Group count
# TFIELDS =                   30 / number of columns
# EXTNAME = 'PHASE3CATALOG'      / FITS Extension name
# TTYPE1  = 'TRANSIENT_ID'       / Label for field 1
# TFORM1  = '50A     '           / Data format of field 1
# TUNIT1  = '' / Physical unit for field 1
# TCOMM1  = 'The master name of the transient' / Description for field 1
# TUCD1   = 'meta.id;meta.main'  / Unified content descriptor of field 1
# TINDX1  =                    T / TRUE if database index exists for field 1
# TPRIC1  =                    T / TRUE if field 1 represents principal parameter
# TTYPE2  = 'TRANSIENT_DISCOVERY_ID' / Label for field 2
# TFORM2  = '50A     '           / Data format of field 2
# TUNIT2  = '' / Physical unit for field 2
# TCOMM2  = 'The name of the transient reported by the discovery survey' / Descrip
# TUCD2   = 'meta.id;'           / Unified content descriptor of field 2
# TINDX2  =                    T / TRUE if database index exists for field 2
# TPRIC2  =                    T / TRUE if field 2 represents principal parameter
# TTYPE3  = 'TRANSIENT_RAJ2000'  / Label for field 3
# TFORM3  = 'E       '           / Data format of field 3
# TUNIT3  = 'deg     '           / Physical unit for field 3
# TCOMM3  = 'RA of the transient in decimal degrees' / Description for field 3
# TUCD3   = 'pos.eq.ra;meta.main' / Unified content descriptor of field 3
# TINDX3  =                    T / TRUE if database index exists for field 3
# TPRIC3  =                    T / TRUE if field 3 represents principal parameter
# TTYPE4  = 'TRANSIENT_DECJ2000' / Label for field 4
# TFORM4  = 'E       '           / Data format of field 4
# TUNIT4  = 'deg     '           / Physical unit for field 4
# TCOMM4  = 'DEC of the transient in decimal degrees' / Description for field 4
# TUCD4   = 'pos.eq.dec;meta.main' / Unified content descriptor of field 4
# TINDX4  =                    T / TRUE if database index exists for field 4
# TPRIC4  =                    T / TRUE if field 4 represents principal parameter
# TTYPE5  = 'TRANSIENT_CLASSIFICATION' / Label for field 5
# TFORM5  = '20A     '           / Data format of field 5
# TUNIT5  = '' / Physical unit for field 5
# TCOMM5  = 'Classification of the transient reported in PESSTO ATels' / Descripti
# TUCD5   = 'meta.code.class;src.class' / Null Representation of field 5
# TINDX5  =                    T / Unified content descriptor of field 5
# TPRIC5  =                    T / TRUE if database index exists for field 5
# TTYPE6  = 'TRANSIENT_CLASSIFICATION_PECULIAR_FLAG' / TRUE if field 5 represents
# TFORM6  = 'I       '           / Label for field 6
# TUNIT6  = '' / Data format of field 6
# TCOMM6  = 'Boolean flag, set to "1" if transient classified as peculiar' / Physi
# TNULL6  =                 9999 / Description for field 6
# TUCD6   = 'meta.code'          / Unified content descriptor of field 6
# TINDX6  = '' / TRUE if database index exists for field 6
# TPRIC6  =                    T / TRUE if field 6 represents principal parameter
# TTYPE7  = 'TRANSIENT_CLASSIFICATION_SOURCE' / Label for field 7
# TFORM7  = '20A     '           / Data format of field 7
# TUNIT7  = '' / Physical unit for field 7
# TCOMM7  = 'The source of the classification' / Description for field 7
# TUCD7   = 'meta.id '           / Null Representation of field 7
# TINDX7  = '' / Unified content descriptor of field 7
# TPRIC7  = '' / TRUE if database index exists for field 7
# TTYPE8  = 'TRANSIENT_CLASSIFICATION_ATEL' / TRUE if field 7 represents principal
# TFORM8  = 'I       '           / Label for field 8
# TUNIT8  = '' / Data format of field 8
# TCOMM8  = 'The number of the ATel  reporting the classification' / Physical unit
# TNULL8  =                    0 / Description for field 8
# TUCD8   = 'meta.id '           / Unified content descriptor of field 8
# TINDX8  = '' / TRUE if database index exists for field 8
# TPRIC8  = '' / TRUE if field 8 represents principal parameter
# TTYPE9  = 'TRANSIENT_CLASSIFICATION_MJD' / Label for field 9
# TFORM9  = 'J       '           / Data format of field 9
# TUNIT9  = 'days    '           / Physical unit for field 9
# TCOMM9  = 'MJD at point of classification' / Description for field 9
# TUCD9   = 'time.epoch'         / Unified content descriptor of field 9
# TINDX9  =                    T / TRUE if database index exists for field 9
# TPRIC9  =                    T / TRUE if field 9 represents principal parameter
# TTYPE10 = 'TRANSIENT_CLASSIFICATION_REDSHIFT' / Label for field 10
# TFORM10 = 'E       '           / Data format of field 10
# TUNIT10 = '' / Physical unit for field 10
# TCOMM10 = 'The redshift of the transient' / Description for field 10
# TUCD10  = 'src.redshift'       / Unified content descriptor of field 10
# TINDX10 =                    T / TRUE if database index exists for field 10
# TPRIC10 =                    T / TRUE if field 10 represents principal parameter
# TTYPE11 = 'TRANSIENT_CLASSIFICATION_PHASE' / Label for field 11
# TFORM11 = '20A     '           / Data format of field 11
# TUNIT11 = '' / Physical unit for field 11
# TCOMM11 = 'The general phase of the transient wrt maximum light' / Description f
# TUCD11  = 'time.phase'         / Null Representation of field 11
# TINDX11 = '' / Unified content descriptor of field 11
# TPRIC11 = '' / TRUE if database index exists for field 11
# TTYPE12 = 'TRANSIENT_CLASSIFICATION_PHASE_DAYS_LOWER_LIMIT' / TRUE if field 11 r
# TFORM12 = 'I       '           / Label for field 12
# TUNIT12 = 'days    '           / Data format of field 12
# TCOMM12 = 'Lower limit of transient phase wrt maximum light' / Physical unit for
# TNULL12 =                 9999 / Description for field 12
# TUCD12  = 'time.phase'         / Null Representation of field 12
# TINDX12 = '' / Unified content descriptor of field 12
# TPRIC12 = '' / TRUE if database index exists for field 12
# TTYPE13 = 'TRANSIENT_CLASSIFICATION_PHASE_DAYS_UPPER_LIMIT' / TRUE if field 12 r
# TFORM13 = 'I       '           / Label for field 13
# TUNIT13 = 'days    '           / Data format of field 13
# TCOMM13 = 'Upper limit of transient phase wrt maximum light' / Physical unit for
# TNULL13 =                 9999 / Description for field 13
# TUCD13  = 'time.phase'         / Unified content descriptor of field 13
# TINDX13 = '' / TRUE if database index exists for field 13
# TPRIC13 = '' / TRUE if field 13 represents principal parameter
# TTYPE14 = 'TRANSIENT_DISCOVERY_MJD' / Label for field 14
# TFORM14 = 'J       '           / Data format of field 14
# TUNIT14 = 'days    '           / Physical unit for field 14
# TCOMM14 = 'MJD at point of transient discovery' / Description for field 14
# TUCD14  = 'time.phase'         / Unified content descriptor of field 14
# TINDX14 =                    T / TRUE if database index exists for field 14
# TPRIC14 =                    T / TRUE if field 14 represents principal parameter
# TTYPE15 = 'TRANSIENT_DISCOVERY_MAG' / Label for field 15
# TFORM15 = 'E       '           / Data format of field 15
# TUNIT15 = 'magnitude of the transient at point of discovery' / Physical unit for
# TCOMM15 = 'Magnitude of the transient at point of discovery' / Description for f
# TUCD15  = 'phot.mag'           / Unified content descriptor of field 15
# TINDX15 = '' / TRUE if database index exists for field 15
# TPRIC15 =                    T / TRUE if field 15 represents principal parameter
# TTYPE16 = 'TRANSIENT_DISCOVERY_MAG_FILTER' / Label for field 16
# TFORM16 = '10A     '           / Data format of field 16
# TUNIT16 = '' / Physical unit for field 16
# TCOMM16 = 'Filter used for discovery magnitude' / Description for field 16
# TUCD16  = 'meta.id;instr.filter' / Null Representation of field 16
# TINDX16 = '' / Unified content descriptor of field 16
# TPRIC16 =                    T / TRUE if database index exists for field 16
# TTYPE17 = 'FOLLOWUP_TARGET'    / TRUE if field 16 represents principal parameter
# TFORM17 = 'I       '           / Label for field 17
# TUNIT17 = '' / Data format of field 17
# TCOMM17 = 'PESSTO follow-up campaign object (Boolean)' / Physical unit for field
# TNULL17 =                 9999 / Description for field 17
# TUCD17  = 'meta.code'          / Null Representation of field 17
# TINDX17 = '' / Unified content descriptor of field 17
# TPRIC17 = '' / TRUE if database index exists for field 17
# TTYPE18 = 'HOST_SEARCH_STAGE'  / TRUE if field 17 represents principal parameter
# TFORM18 = 'I       '           / Label for field 18
# TUNIT18 = '' / Data format of field 18
# TCOMM18 = 'Cross-match stage host galaxy was matched' / Physical unit for field
# TNULL18 =                    0 / Description for field 18
# TUCD18  = 'meta.id '           / Unified content descriptor of field 18
# TINDX18 = '' / TRUE if database index exists for field 18
# TPRIC18 = '' / TRUE if field 18 represents principal parameter
# TTYPE19 = 'HOST_ID '           / Label for field 19
# TFORM19 = '50A     '           / Data format of field 19
# TUNIT19 = '' / Physical unit for field 19
# TCOMM19 = 'The name of an associated host galaxy' / Description for field 19
# TUCD19  = 'meta.id '           / Unified content descriptor of field 19
# TINDX19 = '' / TRUE if database index exists for field 19
# TPRIC19 =                    T / TRUE if field 19 represents principal parameter
# TTYPE20 = 'HOST_RAJ2000'       / Label for field 20
# TFORM20 = 'E       '           / Data format of field 20
# TUNIT20 = 'deg     '           / Physical unit for field 20
# TCOMM20 = 'RA of host galaxy in decimal degrees' / Description for field 20
# TUCD20  = 'pos.eq.ra'          / Unified content descriptor of field 20
# TINDX20 = '' / TRUE if database index exists for field 20
# TPRIC20 =                    T / TRUE if field 20 represents principal parameter
# TTYPE21 = 'HOST_DECJ2000'      / Label for field 21
# TFORM21 = 'E       '           / Data format of field 21
# TUNIT21 = 'deg     '           / Physical unit for field 21
# TCOMM21 = 'DEC of host galaxy in decimal degrees' / Description for field 21
# TUCD21  = 'pos.eq.dec'         / Unified content descriptor of field 21
# TINDX21 = '' / TRUE if database index exists for field 21
# TPRIC21 =                    T / TRUE if field 21 represents principal parameter
# TTYPE22 = 'HOST_OFFSET_N'      / Label for field 22
# TFORM22 = 'E       '           / Data format of field 22
# TUNIT22 = 'deg     '           / Physical unit for field 22
# TCOMM22 = 'The N-S transient-host separation' / Description for field 22
# TUCD22  = 'pos.angDistance'    / Unified content descriptor of field 22
# TINDX22 = '' / TRUE if database index exists for field 22
# TPRIC22 = '' / TRUE if field 22 represents principal parameter
# TTYPE23 = 'HOST_OFFSET_E'      / Label for field 23
# TFORM23 = 'E       '           / Data format of field 23
# TUNIT23 = 'deg     '           / Physical unit for field 23
# TCOMM23 = 'The E-W transient-host separation' / Description for field 23
# TUCD23  = 'pos.angDistance'    / Unified content descriptor of field 23
# TINDX23 = '' / TRUE if database index exists for field 23
# TPRIC23 = '' / TRUE if field 23 represents principal parameter
# TTYPE24 = 'HOST_REDSHIFT_SPEC_SOURCE' / Label for field 24
# TFORM24 = '10A     '           / Data format of field 24
# TUNIT24 = '' / Physical unit for field 24
# TCOMM24 = 'Source of the galaxy spectroscopic redshift' / Description for field
# TUCD24  = 'meta.id '           / Unified content descriptor of field 24
# TINDX24 = '' / TRUE if database index exists for field 24
# TPRIC24 = '' / TRUE if field 24 represents principal parameter
# TTYPE25 = 'HOST_REDSHIFT_SPEC' / Label for field 25
# TFORM25 = 'E       '           / Data format of field 25
# TUNIT25 = '' / Physical unit for field 25
# TCOMM25 = 'Host galaxy spectroscopic redshift' / Description for field 25
# TUCD25  = 'src.redshift'       / Unified content descriptor of field 25
# TINDX25 =                    T / TRUE if database index exists for field 25
# TPRIC25 = '' / TRUE if field 25 represents principal parameter
# TTYPE26 = 'HOST_REDSHIFT_PHOT_SOURCE' / Label for field 26
# TFORM26 = '10A     '           / Data format of field 26
# TUNIT26 = '' / Physical unit for field 26
# TCOMM26 = 'Source of the galaxy photometric redshift' / Description for field 26
# TUCD26  = 'meta.id '           / Unified content descriptor of field 26
# TINDX26 = '' / TRUE if database index exists for field 26
# TPRIC26 = '' / TRUE if field 26 represents principal parameter
# TTYPE27 = 'HOST_REDSHIFT_PHOT' / Label for field 27
# TFORM27 = 'E       '           / Data format of field 27
# TUNIT27 = '' / Physical unit for field 27
# TCOMM27 = 'Host galaxy photometric redshift' / Description for field 27
# TUCD27  = 'src.redshift'       / Unified content descriptor of field 27
# TINDX27 =                    T / TRUE if database index exists for field 27
# TPRIC27 = '' / TRUE if field 27 represents principal parameter
# TTYPE28 = 'HOST_REDSHIFT_PHOT_ERR' / Label for field 28
# TFORM28 = 'E       '           / Data format of field 28
# TUNIT28 = '' / Physical unit for field 28
# TCOMM28 = 'Host galaxy photometric redshift error' / Description for field 28
# TUCD28  = 'stat.error;src.redshift' / Unified content descriptor of field 28
# TINDX28 = '' / TRUE if database index exists for field 28
# TPRIC28 = '' / TRUE if field 28 represents principal parameter
# TTYPE29 = 'TRANSIENT_IAU_ID'   / Label for field 29
# TFORM29 = '50A     '           / Data format of field 29
# TUNIT29 = '' / Physical unit for field 29
# TCOMM29 = 'The offical IAU identification of the object' / Description for field
# TUCD29  = 'meta.id;'           / Unified content descriptor of field 29
# TINDX29 = '' / TRUE if database index exists for field 29
# TPRIC29 = '' / TRUE if field 29 represents principal parameter
# TTYPE30 = 'TRANSIENT_ALTERNATIVE_IDS' / Label for field 30
# TFORM30 = '200A    '           / Data format of field 30
# TUNIT30 = '' / Physical unit for field 30
# TCOMM30 = 'The object identifications as assigned by other surveys' / Descriptio
# TUCD30  = 'meta.id;'           / Unified content descriptor of field 30
# TINDX30 = '' / TRUE if database index exists for field 30
# TPRIC30 = '' / TRUE if field 30 represents principal parameter
# CHECKSUM= 'Oa1AOX19Oa1AOU17'   / HDU checksum updated 2017-08-14T13:45:06
# DATASUM = '618876061'          / data unit checksum updated 2017-08-14T13:45:06

# %%
# Has BINTABLE HDU got any data?
print(hdu_list[1].data is not None)
# Out:
# True

# %% [markdown]
# We realize that the first header is the file metadata, which contains information about the catalogue itself. On the other hand, the second header is a binary table with the contents of the catalogue.

# %%
# Transform Catalogue to Pandas
transient_df = Table(hdu_list[1].data).to_pandas()
# Close HDU file
hdu_list.close()

# %% [markdown]
# #### Sample Row

# %%
transient_df.iloc[0]
# Out:
# TRANSIENT_ID                                                   SN2013U
# TRANSIENT_DISCOVERY_ID                             PSNJ100112000019423
# TRANSIENT_RAJ2000                                                150.3
# TRANSIENT_DECJ2000                                            0.328417
# TRANSIENT_CLASSIFICATION                                         SN Ia
# TRANSIENT_CLASSIFICATION_PECULIAR_FLAG                               1
# TRANSIENT_CLASSIFICATION_SOURCE                              CBET 3410
# TRANSIENT_CLASSIFICATION_ATEL                                        0
# TRANSIENT_CLASSIFICATION_MJD                                     56329
# TRANSIENT_CLASSIFICATION_REDSHIFT                              0.03451
# TRANSIENT_CLASSIFICATION_PHASE                                 pre-max
# TRANSIENT_CLASSIFICATION_PHASE_DAYS_LOWER_LIMIT                     -7
# TRANSIENT_CLASSIFICATION_PHASE_DAYS_UPPER_LIMIT                     -4
# TRANSIENT_DISCOVERY_MJD                                          56297
# TRANSIENT_DISCOVERY_MAG                                           16.6
# TRANSIENT_DISCOVERY_MAG_FILTER                              unfiltered
# FOLLOWUP_TARGET                                                      1
# HOST_SEARCH_STAGE                                                    1
# HOST_ID                                                   CGCG 008-023
# HOST_RAJ2000                                                   150.299
# HOST_DECJ2000                                                  0.32934
# HOST_OFFSET_N                                                  -0.0009
# HOST_OFFSET_E                                                   0.0005
# HOST_REDSHIFT_SPEC_SOURCE                                          NED
# HOST_REDSHIFT_SPEC                                            0.034506
# HOST_REDSHIFT_PHOT_SOURCE                                         SDSS
# HOST_REDSHIFT_PHOT                                              0.0831
# HOST_REDSHIFT_PHOT_ERR                                           0.026
# TRANSIENT_IAU_ID                                               SN2013U
# TRANSIENT_ALTERNATIVE_IDS                                         NULL
# Name: 0, dtype: object

# %% [markdown]
# # Imaging Data Exploration

# %% [markdown]
# #### Filename for the transient in a given time

# %%
sample_img_name = 'ASASSN-14ko_20141221_J_merge_57621_1'
sample_img_filename = 'ASASSN-14ko_20141221_J_merge_57621_1' + '.fits'

# %%
hdu_list = fits.open(imaging_path + sample_img_filename)
hdu_list.info()
# Out:
# Filename: ./data/PESSTO/Imaging Data/ASASSN-14ko_20141221_J_merge_57621_1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     277   (1222, 1204)   float32

# %%
hdu_list[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1222
# NAXIS2  =                 1204
# ORIGIN  = 'ESO     '           / European Southern Observatory
# IRAF-TLM= '2016-08-21T11:35:03' / Time of last modification
# DATE    = '2016-08-21T11:14:41' / UT date when this file was written
# TELESCOP= 'ESO-NTT '           / ESO Telescope Name
# INSTRUME= 'SOFI    '           / Instrument used.
# OBJECT  = 'ASASSN-14ko'        / Original target.
# RA      =             81.32997 / 05:25:19.19 RA (J2000) pointing (deg)
# DEC     =            -46.00872 / -46:00:31.3 DEC (J2000) pointing (deg)
# EQUINOX =               2000.0 / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# EXPTIME =                400.0 / Total integration time
# MJD-OBS =        57013.3283916 / MJD start (2014-12-22 07:52:53.034234)
# DATE-OBS= '2014-12-22T07:52:53' / Date of observation
# UTC     =              28373.0 / 06:42:14.000 UTC at start (sec)
# LST     =            33187.816 / 15:29:43.586 LST at start (sec)
# PI-COI  = 'Smartt  '           / PI-COI name.
# OBSERVER= '' / Name of observer.
# CTYPE1  = 'RA---TAN'           / pixel coordinate system
# CTYPE2  = 'DEC--TAN'           / pixel coordinate system
# CRVAL1  =        81.3309660705 / RA at ref pixel
# CRVAL2  =       -46.0116377471 / DEC at ref pixel
# CRPIX1  =        649.027065206 / Ref pixel in X
# CRPIX2  =        593.765396181 / Ref pixel in Y
# CD1_1   =   -4.06823734458E-08 / Transformation matrix element
# CD2_2   =    4.06609784603E-08 / Transformation matrix element
# HIERARCH ESO ADA ABSROT END = 132.65723 / Abs rot angle at exp end (deg)
# HIERARCH ESO ADA ABSROT START = 133.28987 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA GUID STATUS = 'OFF     ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 0.0 / Position angle at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.IRACE-1.44' / Diction
# HIERARCH ESO DET EXP NO = 107727 / Unique exposure ID number
# HIERARCH ESO DET FRAM TYPE = 'INT     ' / Type of frame
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.ISAAC_ICS-0.1' / Data dictionary
# HIERARCH ESO INS FILT1 ID = 'J       ' / Filter unique id.
# HIERARCH ESO INS FILT1 NAME = 'J       ' / Filter name.
# HIERARCH ESO INS FILT1 NO = 11 / Filter wheel position index.
# HIERARCH ESO INS ID = 'SOFI/HW 1.0/SW 38575/' / Instrument ID.
# HIERARCH ESO INS MODE = 'LARGE_FIELD_IMAGING' / Instrument mode used.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-1.11' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 2019.0 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID = 100364773 / Observation block ID
# HIERARCH ESO OBS NAME = 'ASASSN-14ko_JHK_J_16_0__17_5__on' / OB name
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 2931 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '191.D-0935(H)' / ESO program identification
# HIERARCH ESO OBS START = '2014-12-22T07:52:23' / OB start time
# HIERARCH ESO OBS TARG NAME = 'ASASSN-14ko' / OB target name
# HIERARCH ESO OBS TPLNO = 2 / Template number within OB
# HIERARCH ESO TEL AIRM END = 1.471 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.462 / Airmass at start
# HIERARCH ESO TEL ALT = 43.101 / Alt angle at start (deg)
# HIERARCH ESO TEL AMBI FWHM END = 0.88 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI FWHM START = 0.88 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI PRES END = 768.3 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI PRES START = 768.3 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI RHUM = 20.0 / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP = 11.05 / Observatory ambient temperature qu
# HIERARCH ESO TEL AMBI WINDDIR = 34.0 / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI WINDSP = 8.9 / Observatory ambient wind speed que
# HIERARCH ESO TEL AZ = 52.784 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL CHOP ST = F / True when chopping is active
# HIERARCH ESO TEL DATE = '2009-06-05T01:00:00' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL FOCU ID = 'NA      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 38.501 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE = 5.36 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE = -3.89 / M2 setting (mm)
# HIERARCH ESO TEL GEOELEV = 2377.0 / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT = -29.2584 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON = -70.7345 / Tel geo longitude (+=East) (deg)
# HIERARCH ESO TEL ID = 'v 254740' / TCS version number
# HIERARCH ESO TEL MOON DEC = -17.83344 / -17:50:00.3 DEC (J2000) (deg)
# HIERARCH ESO TEL MOON RA = 274.678212 / 18:18:42.77 RA (J2000) (deg)
# HIERARCH ESO TEL OPER = 'I. CONDOR' / Telescope Operator
# HIERARCH ESO TEL PARANG END = 90.01900000000001 / Parallactic angle at end (deg)
# HIERARCH ESO TEL PARANG START = 89.694 / Parallactic angle at start (deg)
# HIERARCH ESO TEL TARG ALPHA = 52518.13 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL TARG DELTA = -460020.3 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000.0 / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (default J=Julian)
# HIERARCH ESO TEL TARG EQUINOX = 2000.0 / Equinox
# HIERARCH ESO TEL TARG PARALLAX = 0.0 / Parallax
# HIERARCH ESO TEL TARG PMA = 0.0 / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0.0 / Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL = 0.0 / Radial velocity
# HIERARCH ESO TEL TH M1 TEMP = -1.0 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL TSS TEMP8 = 9.210000000000001 / Temperature Sensing System
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO = 1 / Exposure number within template
# HIERARCH ESO TPL ID = 'SOFI_img_obs_AutoJitterArray_1' / Template signature ID
# HIERARCH ESO TPL NAME = '' / Template name
# HIERARCH ESO TPL NEXP = 4 / Number of exposures within templat
# HIERARCH ESO TPL PRESEQ = 'SOFI_img_obs_AutoJitterArray_1.seq' / Sequencer scrip
# HIERARCH ESO TPL START = '2014-12-22T07:52:40' / TPL start time
# HIERARCH ESO TPL VERSION = '@(#) $Revision: 132887 $' / Version of the template
# ORIGFILE= 'ASASSN-14ko_20141221_J_merge_57621_1.fits' / Original File Name
# ARCFILE = 'ADP.2016-11-17T12:50:58.911.fits' / Archive File Name
# CHECKSUM= 'hBkFi9k9hAkCh9k9'   / HDU checksum updated 2016-12-08T14:42:54
# DATASUM = '4191078660'         / data unit checksum updated 2016-11-11T15:52:31
# WCSDIM  =                    2
# LTM1_1  =                  1.0
# LTM2_2  =                  1.0
# WAT0_001= 'system=image'
# WAT1_001= 'wtype=tan axtype=ra'
# WAT2_001= 'wtype=tan axtype=dec'
# TRIM    = 'Aug 21 13:07 Trim data section is [1:1024,1:1007]'
# CCDSEC  = '[1:1024,1:1007]'
# BIASSEC = '[1:1024,1:1007]'
# CCDMEANT=           1156252040
# CCDPROC = 'Aug 21 13:07 CCD processing done'
# FLATCOR = 'flat_20140428_J_56778_1.fits'
# FILTER  = 'J       '           / Filter name
# PROV1   = 'SOFI.2014-12-22T07:52:53.038.fits' / Originating file
# SINGLEXP=                    F / TRUE if resulting from single exposure
# M_EPOCH =                    F / TRUE if resulting from multiple epochs
# FILETYPE=                32216 / pre-reduced image
# NCOMBINE=                    4 / Number of raw science data
# TRACE1  = 'ASASSN-14ko_20141221_J_57621_1_sky.fits' / Originating file
# AIRMASS =        1.46905089004 / mean airmass computed with astcalc
# CD2_1   =   -8.00140531527E-05 / Transformation matrix element
# CD1_2   =   -7.99719735156E-05 / Transformation matrix element
# MBKG    =        746.999023438 / background level
# ASTROMET= '0.171 0.248 25'     / rmsx rmsy nstars
# CRDER2  = 6.88888888888999E-05 / Random error (degree)
# CSYER1  =             2.78E-05 / Systematic error (RA_m - Ra_ref)
# PSF_FWHM=          0.990862272 / Spatial resolution (arcsec)
# CRDER1  =             4.75E-05 / Random error (degree)
# CUNIT1  = 'deg     '           / unit of the coord. trans.
# ELLIPTIC=                0.075 / Average ellipticity of point sources
# CUNIT2  = 'deg     '           / unit of the coord. trans.
# CSYER2  =             2.78E-05 / Systematic error (DEC_m - DEC_ref)
# PHOTZP  =        26.0608712855 / MAG=-2.5*log(data)+PHOTZP
# PHOTZPER=       0.010321744783 / error in PHOTZP
# FLUXCAL = 'ABSOLUTE'           / Type of flux calibration
# PHOTSYS = 'VEGA    '           / Photometric system VEGA or AB
# ABMAGSAT=    12.40484336142718 / Saturation limit for point sources (AB mags)
# ABMAGLIM=     20.0082364045348 / 5-sigma limiting AB magnitude for point sources
# PIXSCALE=                0.288 / pixel/scale (arcsec)
# EFFRON  =    3.362994729838757 / Effective readout noise per output (e-)
# PROG_ID = '191.D-0935(H)'      / ESO program identification
# OBSTECH = 'IMAGE   '           / Observation technique
# REFERENC= 'Smartt et al 2014'  / Bibliographic reference
# PROCSOFT= 'ntt_2.2.10'         / pipeline version
# OBID1   =            100364773 / Observation block ID
# DATAMAX =        14689.9550781 / Maximum pixel value
# DATAMIN =       -98.2269287109 / Minimal pixel value
# DETRON  =                 12.0 / Readout noise per output (e-)
# GAIN    =        14.3999999856 / Conversion from electrons to ADU
# PRODCATG= 'SCIENCE.IMAGE'      / Data product category
# MJD-END =        57013.3334628 / MJD-END = MJD-OBS + JD(exptime)
# QUALITY = 'Final   '           / Final or Fast reduction
# BUNIT   = 'ADU     '           / pixel units
# TEXPTIME=                400.0 / Total integ. time of all exposure
# HIERARCH ESO SEQ RELOFFSETX = 0.0 / relative X offset
# HIERARCH ESO SEQ RELOFFSETY = 0.0 / relative Y offset
# HIERARCH ESO SEQ CUMOFFSETX = 69.444444 / cummulative X offset
# HIERARCH ESO SEQ CUMOFFSETY = 69.444444 / cummulative Y offset
# HIERARCH ESO SEQ POISSON = 10 / Homogeneity factor for Poisson ran
# HIERARCH ESO SEQ CUMOFFSETA = 20.0 / cummulative alpha offset
# HIERARCH ESO SEQ CUMOFFSETD = 20.0 / cummulative delta offset
# HIERARCH ESO DPR CATG = 'SCIENCE ' / Observation category
# HIERARCH ESO DPR TYPE = 'OBJECT  ' / Observation type
# HIERARCH ESO DPR TECH = 'IMAGE   ' / Observation technique
# HIERARCH ESO INS TIME = '2014-12-22T07:54:40' / Aquired status time
# HIERARCH ESO INS PIXSCALE = 0.288 / Pixel scale
# HIERARCH ESO INS TEMP-MON TEMP1 = 77.26000000000001 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME1 = 'Cool Down' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP2 = 65.88 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME2 = 'Camera Unit' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP3 = 100.27 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME3 = 'Radiation Shield' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP4 = 65.48 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME4 = 'Mirror  ' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP5 = 67.31 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME5 = 'Collimator' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP6 = 64.3 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME6 = 'Warm-Up ' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP7 = 143.55 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME7 = 'Sorption' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP8 = 69.84 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME8 = 'Aperture Wheel' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP9 = 10.4 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME9 = 'Ambient ' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP10 = 2.3 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME10 = 'Delta T ' / Sensor placement
# HIERARCH ESO INS TEMP-DETSW = 65.518 / Temp. of detector SW
# HIERARCH ESO INS TEMP-DETSW SET = 65.0 / Set temp. of detector SW
# HIERARCH ESO INS TEMP-VACP = 9.82399999999999E-07 / Vessel pressure
# HIERARCH ESO INS OPTI1 ID = 'large_field' / OPTIi unique ID
# HIERARCH ESO INS OPTI1 NAME = 'large_field' / OPTIi name
# HIERARCH ESO INS OPTI1 NO = 6 / OPTIi slot number
# HIERARCH ESO INS OPTI1 TYPE = 'MASK    ' / OPTIi element
# HIERARCH ESO INS COLLIM ENC = -18076 / Collimator encoder position
# HIERARCH ESO INS FILT1 TYPE = 'FILTER  ' / FILTi element
# HIERARCH ESO INS FILT2 ID = 'open    ' / FILTi unique ID
# HIERARCH ESO INS FILT2 NAME = 'open    ' / FILTi name
# HIERARCH ESO INS FILT2 NO = 4 / FILTi slot number
# HIERARCH ESO INS FILT2 TYPE = 'FREE    ' / FILTi element
# HIERARCH ESO INS OPTI2 ID = 'open    ' / OPTIi unique ID
# HIERARCH ESO INS OPTI2 NAME = 'open    ' / OPTIi name
# HIERARCH ESO INS OPTI2 NO = 8 / OPTIi slot number
# HIERARCH ESO INS OPTI2 TYPE = 'FREE    ' / OPTIi element
# HIERARCH ESO INS OPTI3 ID = 'LF      ' / OPTIi unique ID
# HIERARCH ESO INS OPTI3 NAME = 'LF      ' / OPTIi name
# HIERARCH ESO INS OPTI3 NO = 4 / OPTIi slot number
# HIERARCH ESO INS OPTI3 TYPE = 'OBJECTIVE' / OPTIi element
# HIERARCH ESO DET FRAM NO = 1 / Frame number
# HIERARCH ESO DET FRAM UTC = '2014-12-22T07:54:39' / Time Recv Frame
# HIERARCH ESO DET EXP UTC = '2014-12-22T07:54:40' / File Creation Time
# HIERARCH ESO DET EXP NAME = 'name_J_0017' / Exposure Name
# HIERARCH ESO DET CHIP ID = 'ESO-Hawaii' / Detector ID
# HIERARCH ESO DET FILE CUBE ST = F / Data Cube On/Off
# HIERARCH ESO DET CON OPMODE = 'NORMAL  ' / Operational Mode
# HIERARCH ESO DET IRACE SEQCONT = F / Sequencer Cont. Mode
# HIERARCH ESO DET CHIP NAME = 'Hawaii  ' / Detector name
# HIERARCH ESO DET CHIP TYPE = 'IR      ' / The Type of Det Chip
# HIERARCH ESO DET CHIP NX = 1024 / Pixels in X
# HIERARCH ESO DET CHIP NY = 1024 / Pixels in Y
# HIERARCH ESO DET DIT = 20.0 / Integration Time
# HIERARCH ESO DET NCORRS = 2 / Read-Out Mode
# HIERARCH ESO DET NCORRS NAME = 'Double  ' / Read-Out Mode Name
# HIERARCH ESO DET MODE NAME = '' / DCS Detector Mode
# HIERARCH ESO DET DITDELAY = 0.0 / Pause Between DITs
# HIERARCH ESO DET NDIT = 5 / # of Sub-Integrations
# HIERARCH ESO DET NDITSKIP = 0 / DITs skipped at 1st.INT
# HIERARCH ESO DET CHOP NCYCLES = 4 / # of Chop Cycles
# HIERARCH ESO DET CHOP CYCSKIP = 0 / # of Chop Cycles to Skip
# HIERARCH ESO DET CHOP ST = F / Chopping On/Off
# HIERARCH ESO DET RSPEED = 4 / Read-Speed Factor
# HIERARCH ESO DET RSPEEDADD = 0 / Read-Speed Add
# HIERARCH ESO DET WIN TYPE = 0 / Win-Type: 0=SW/1=HW
# HIERARCH ESO DET WIN STARTX = 1.0 / Lower Left X Ref
# HIERARCH ESO DET WIN STARTY = 1.0 / Lower left Y Ref
# HIERARCH ESO DET WIN NX = 1024 / # of Pixels in X
# HIERARCH ESO DET WIN NY = 1024 / # of Pixels in Y
# HIERARCH ESO DET IRACE ADC1 NAME = 'ADC-G1  ' / Name for ADC Board
# HIERARCH ESO DET IRACE ADC1 HEADER = 0 / Header of ADC Board
# HIERARCH ESO DET IRACE ADC1 ENABLE = 1 / Enable ADC Board (0/1)
# HIERARCH ESO DET IRACE ADC1 FILTER1 = 1 / ADC Filter Adjustment
# HIERARCH ESO DET IRACE ADC1 FILTER2 = 0 / ADC Filter Adjustment
# HIERARCH ESO DET IRACE ADC1 DELAY = 7 / ADC Delay Adjustment
# HIERARCH ESO DET CHOP FREQ = 0.0 / Chopping Frequency
# HIERARCH ESO OCS WCS-RTD ST = T / Update RTD with WCS info.
# HIERARCH ESO OCS COMP ID = 'SW Version 33645 2000-03-04 01:28:56Z' / OS Soft
# HIERARCH ESO OCS DID = 'ESO-VLT-DIC.SOFI_OS-0.1' / Data dictionary for O
# HIERARCH ESO OCS SELECT-ARM = 'SW      ' / Detector arm
# HIERARCH ESO DET CHIP PXSPACE = 1.8E-05 / Pixel-Pixel Spacing
# CROSSTAL= 'True    '
# ILLUMCOR= 'illum_20140428_J_56778_1.fits' / illumination correction
# DIT     =                 20.0 / Integration Time
# NDIT    =                    5 / Number of sub-integrations
# PROV2   = 'SOFI.2014-12-22T07:54:42.549.fits' / Originating file
# TRACE2  = 'ASASSN-14ko_20141221_J_57621_2_sky.fits' / Originating file
# PROV3   = 'SOFI.2014-12-22T07:56:32.308.fits' / Originating file
# TRACE3  = 'ASASSN-14ko_20141221_J_57621_3_sky.fits' / Originating file
# PROV4   = 'SOFI.2014-12-22T07:58:22.187.fits' / Originating file
# TRACE4  = 'ASASSN-14ko_20141221_J_57621_4_sky.fits' / Originating file
# NTCRPIX1=                541.3 / reference x pixel of combined image
# NTCRPIX2=                541.7 / reference y pixel of combined image
# NUSTEP  =                    0 / Number of microstep positions
# NOFFSETS=                    4 / Number of offset positions
# NJITTER =                    1 / Number of microstep positions
# ASSON1  = 'ASASSN-14ko_20141221_J_merge_57621_1.weight.fits' / Name of associate
# ZPHJH   = '' / None
# DATA_REL= 'SSDR3   '           / Data Release Version
# P3ORIG  = 'EDP     '           / ESO external data product

# %%
hdu_list[0].header[24:28]
# Out:
# CRVAL1  =        81.3309660705 / RA at ref pixel
# CRVAL2  =       -46.0116377471 / DEC at ref pixel
# CRPIX1  =        649.027065206 / Ref pixel in X
# CRPIX2  =        593.765396181 / Ref pixel in Y

# %%
# CRPIX
X = hdu_list[0].header['CRPIX1']
Y = hdu_list[0].header['CRPIX2']
X,Y
# Out:
# (649.027065206, 593.765396181)

# %%
# NTCRPIX
# X = hdu_list[0].header['NTCRPIX1']
# Y = hdu_list[0].header['NTCRPIX2']
# X,Y

# %%
image_data = hdu_list[0].data
hdu_list.close()
#del hdu_list

# %% [markdown]
# ### Display images

# %% [markdown]
# ### Original Image

# %%
plt.figure(figsize=(7,7))
plt.imshow(image_data, origin='lower', cmap='gray')
plt.plot([ X ],[Y], 'r+')

# %%
#image_data /= 255.0
minpx = np.mean(image_data)-2.5*np.std(image_data) 
maxpx = np.mean(image_data)+2.5*np.std(image_data)

plt.figure(figsize=(7,7))
plt.imshow(image_data, origin='lower', cmap='gray', vmin=minpx, vmax=maxpx)
plt.plot([ X ],[Y], 'r+')

# %%
from PIL import Image
side = 150
s = side / 2
img = Image.fromarray(image_data).crop( (X-s,Y-s, X+s, Y+s))
plt.figure(figsize=(8,8))
crop = np.copy(np.asarray(img))
plt.imshow(crop, origin='lower', cmap='gray', vmin=minpx, vmax=maxpx)
plt.plot([s],[s], 'r+')

# %% [markdown]
# ## Imaging Weights Data Exploration

# %%
sample_img_weight_filename = sample_img_name + '.weight.fits'
hdu_list = fits.open(imaging_path + sample_img_weight_filename)
hdu_list.info()
# Out:
# Filename: ./data/PESSTO/Imaging Data/ASASSN-14ko_20141221_J_merge_57621_1.weight.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     257   (1222, 1204)   float32

# %%
hdu_list[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1222
# NAXIS2  =                 1204
# ORIGIN  = 'ESO     '           / European Southern Observatory
# IRAF-TLM= '2016-08-21T11:34:57' / Time of last modification
# DATE    = '2016-08-21T11:14:41' / UT date when this file was written
# TELESCOP= 'ESO-NTT '           / ESO Telescope Name
# INSTRUME= 'SOFI    '           / Instrument used.
# OBJECT  = 'ASASSN-14ko'        / Original target.
# RA      =             81.32997 / 05:25:19.19 RA (J2000) pointing (deg)
# DEC     =            -46.00872 / -46:00:31.3 DEC (J2000) pointing (deg)
# EQUINOX =               2000.0 / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# EXPTIME =                400.0 / Total integration time
# MJD-OBS =        57013.3283916 / MJD start (2014-12-22 07:52:53.034234)
# DATE-OBS= '2014-12-22T07:52:53' / Date of observation
# UTC     =              28373.0 / 06:42:14.000 UTC at start (sec)
# LST     =            33187.816 / 15:29:43.586 LST at start (sec)
# PI-COI  = 'Smartt  '           / PI-COI name.
# OBSERVER= '' / Name of observer.
# CTYPE1  = 'RA---TAN'           / pixel coordinate system
# CTYPE2  = 'DEC--TAN'           / pixel coordinate system
# CRVAL1  =        81.3334369638 / RA at ref pixel
# CRVAL2  =       -46.0007586836 / DEC at ref pixel
# CRPIX1  =                611.5 / Ref pixel in X
# CRPIX2  =                602.5 / Ref pixel in Y
# CD1_1   = -7.9999997978999E-05 / Transformation matrix element
# CD2_2   = 7.99999979789999E-05 / Transformation matrix element
# HIERARCH ESO ADA ABSROT END = 132.65723 / Abs rot angle at exp end (deg)
# HIERARCH ESO ADA ABSROT START = 133.28987 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA GUID STATUS = 'OFF     ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 0.0 / Position angle at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.IRACE-1.44' / Diction
# HIERARCH ESO DET EXP NO = 107727 / Unique exposure ID number
# HIERARCH ESO DET FRAM TYPE = 'INT     ' / Type of frame
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.ISAAC_ICS-0.1' / Data dictionary
# HIERARCH ESO INS FILT1 ID = 'J       ' / Filter unique id.
# HIERARCH ESO INS FILT1 NAME = 'J       ' / Filter name.
# HIERARCH ESO INS FILT1 NO = 11 / Filter wheel position index.
# HIERARCH ESO INS ID = 'SOFI/HW 1.0/SW 38575/' / Instrument ID.
# HIERARCH ESO INS MODE = 'LARGE_FIELD_IMAGING' / Instrument mode used.
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-1.11' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 2019.0 / Expected execution time
# HIERARCH ESO OBS GRP = '0       ' / linked blocks
# HIERARCH ESO OBS ID = 100364773 / Observation block ID
# HIERARCH ESO OBS NAME = 'ASASSN-14ko_JHK_J_16_0__17_5__on' / OB name
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 2931 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '191.D-0935(H)' / ESO program identification
# HIERARCH ESO OBS START = '2014-12-22T07:52:23' / OB start time
# HIERARCH ESO OBS TARG NAME = 'ASASSN-14ko' / OB target name
# HIERARCH ESO OBS TPLNO = 2 / Template number within OB
# HIERARCH ESO TEL AIRM END = 1.471 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.462 / Airmass at start
# HIERARCH ESO TEL ALT = 43.101 / Alt angle at start (deg)
# HIERARCH ESO TEL AMBI FWHM END = 0.88 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI FWHM START = 0.88 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI PRES END = 768.3 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI PRES START = 768.3 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI RHUM = 20.0 / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP = 11.05 / Observatory ambient temperature qu
# HIERARCH ESO TEL AMBI WINDDIR = 34.0 / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI WINDSP = 8.9 / Observatory ambient wind speed que
# HIERARCH ESO TEL AZ = 52.784 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL CHOP ST = F / True when chopping is active
# HIERARCH ESO TEL DATE = '2009-06-05T01:00:00' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL FOCU ID = 'NA      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 38.501 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE = 5.36 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE = -3.89 / M2 setting (mm)
# HIERARCH ESO TEL GEOELEV = 2377.0 / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT = -29.2584 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON = -70.7345 / Tel geo longitude (+=East) (deg)
# HIERARCH ESO TEL ID = 'v 254740' / TCS version number
# HIERARCH ESO TEL MOON DEC = -17.83344 / -17:50:00.3 DEC (J2000) (deg)
# HIERARCH ESO TEL MOON RA = 274.678212 / 18:18:42.77 RA (J2000) (deg)
# HIERARCH ESO TEL OPER = 'I. CONDOR' / Telescope Operator
# HIERARCH ESO TEL PARANG END = 90.01900000000001 / Parallactic angle at end (deg)
# HIERARCH ESO TEL PARANG START = 89.694 / Parallactic angle at start (deg)
# HIERARCH ESO TEL TARG ALPHA = 52518.13 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL TARG DELTA = -460020.3 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000.0 / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (default J=Julian)
# HIERARCH ESO TEL TARG EQUINOX = 2000.0 / Equinox
# HIERARCH ESO TEL TARG PARALLAX = 0.0 / Parallax
# HIERARCH ESO TEL TARG PMA = 0.0 / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0.0 / Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL = 0.0 / Radial velocity
# HIERARCH ESO TEL TH M1 TEMP = -1.0 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL TSS TEMP8 = 9.210000000000001 / Temperature Sensing System
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO = 1 / Exposure number within template
# HIERARCH ESO TPL ID = 'SOFI_img_obs_AutoJitterArray_1' / Template signature ID
# HIERARCH ESO TPL NAME = '' / Template name
# HIERARCH ESO TPL NEXP = 4 / Number of exposures within templat
# HIERARCH ESO TPL PRESEQ = 'SOFI_img_obs_AutoJitterArray_1.seq' / Sequencer scrip
# HIERARCH ESO TPL START = '2014-12-22T07:52:40' / TPL start time
# HIERARCH ESO TPL VERSION = '@(#) $Revision: 132887 $' / Version of the template
# ORIGFILE= 'ASASSN-14ko_20141221_J_merge_57621_1.weight.fits' / Original File Nam
# ARCFILE = 'ADP.2016-11-17T12:50:58.912.fits' / Archive File Name
# CHECKSUM= 'ApDFDoDDAoDDAoDD'   / HDU checksum updated 2016-12-08T14:42:54
# DATASUM = '4044395413'         / data unit checksum updated 2016-11-11T15:52:31
# WCSDIM  =                    2
# LTM1_1  =                  1.0
# LTM2_2  =                  1.0
# WAT0_001= 'system=image'
# WAT1_001= 'wtype=tan axtype=ra'
# WAT2_001= 'wtype=tan axtype=dec'
# TRIM    = 'Aug 21 13:07 Trim data section is [1:1024,1:1007]'
# CCDSEC  = '[1:1024,1:1007]'
# BIASSEC = '[1:1024,1:1007]'
# CCDMEANT=           1156252040
# CCDPROC = 'Aug 21 13:07 CCD processing done'
# FLATCOR = 'flat_20140428_J_56778_1.fits'
# FILTER  = 'J       '           / Filter name
# PROV1   = 'SOFI.2014-12-22T07:52:53.038.fits' / Originating file
# SINGLEXP=                    F / TRUE if resulting from single exposure
# M_EPOCH =                    F / TRUE if resulting from multiple epochs
# FILETYPE=                31214 / pre-reduced image
# NCOMBINE=                    4 / Number of raw science data
# TRACE1  = 'ASASSN-14ko_20141221_J_57621_1_sky.fits' / Originating file
# AIRMASS =        1.46905089004 / mean airmass computed with astcalc
# MBKG    =        746.999023438 / background level
# PIXSCALE=                0.288 / pixel/scale (arcsec)
# PROG_ID = '191.D-0935(H)'      / ESO program identification
# OBSTECH = 'IMAGE   '           / Observation technique
# REFERENC= 'Smartt et al 2014'  / Bibliographic reference
# PROCSOFT= 'ntt_2.2.10'         / pipeline version
# OBID1   =            100364773 / Observation block ID
# DATAMAX =       0.138137251139 / Maximum pixel value
# DATAMIN =                  0.0 / Minimal pixel value
# DETRON  =                 12.0 / Readout noise per output (e-)
# GAIN    =        14.3999999856 / Conversion from electrons to ADU
# PRODCATG= 'ANCILLARY.WEIGHTMAP' / Data product category
# MJD-END =        57013.3334628 / MJD-END = MJD-OBS + JD(exptime)
# QUALITY = 'Final   '           / Final or Fast reduction
# BUNIT   = 'ADU     '           / pixel units
# TEXPTIME=                400.0 / Total integ. time of all exposure
# HIERARCH ESO SEQ RELOFFSETX = 0.0 / relative X offset
# HIERARCH ESO SEQ RELOFFSETY = 0.0 / relative Y offset
# HIERARCH ESO SEQ CUMOFFSETX = 69.444444 / cummulative X offset
# HIERARCH ESO SEQ CUMOFFSETY = 69.444444 / cummulative Y offset
# HIERARCH ESO SEQ POISSON = 10 / Homogeneity factor for Poisson ran
# HIERARCH ESO SEQ CUMOFFSETA = 20.0 / cummulative alpha offset
# HIERARCH ESO SEQ CUMOFFSETD = 20.0 / cummulative delta offset
# HIERARCH ESO DPR CATG = 'SCIENCE ' / Observation category
# HIERARCH ESO DPR TYPE = 'OBJECT  ' / Observation type
# HIERARCH ESO DPR TECH = 'IMAGE   ' / Observation technique
# HIERARCH ESO INS TIME = '2014-12-22T07:54:40' / Aquired status time
# HIERARCH ESO INS PIXSCALE = 0.288 / Pixel scale
# HIERARCH ESO INS TEMP-MON TEMP1 = 77.26000000000001 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME1 = 'Cool Down' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP2 = 65.88 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME2 = 'Camera Unit' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP3 = 100.27 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME3 = 'Radiation Shield' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP4 = 65.48 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME4 = 'Mirror  ' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP5 = 67.31 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME5 = 'Collimator' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP6 = 64.3 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME6 = 'Warm-Up ' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP7 = 143.55 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME7 = 'Sorption' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP8 = 69.84 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME8 = 'Aperture Wheel' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP9 = 10.4 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME9 = 'Ambient ' / Sensor placement
# HIERARCH ESO INS TEMP-MON TEMP10 = 2.3 / Status temp. scanner
# HIERARCH ESO INS TEMP-MON NAME10 = 'Delta T ' / Sensor placement
# HIERARCH ESO INS TEMP-DETSW = 65.518 / Temp. of detector SW
# HIERARCH ESO INS TEMP-DETSW SET = 65.0 / Set temp. of detector SW
# HIERARCH ESO INS TEMP-VACP = 9.82399999999999E-07 / Vessel pressure
# HIERARCH ESO INS OPTI1 ID = 'large_field' / OPTIi unique ID
# HIERARCH ESO INS OPTI1 NAME = 'large_field' / OPTIi name
# HIERARCH ESO INS OPTI1 NO = 6 / OPTIi slot number
# HIERARCH ESO INS OPTI1 TYPE = 'MASK    ' / OPTIi element
# HIERARCH ESO INS COLLIM ENC = -18076 / Collimator encoder position
# HIERARCH ESO INS FILT1 TYPE = 'FILTER  ' / FILTi element
# HIERARCH ESO INS FILT2 ID = 'open    ' / FILTi unique ID
# HIERARCH ESO INS FILT2 NAME = 'open    ' / FILTi name
# HIERARCH ESO INS FILT2 NO = 4 / FILTi slot number
# HIERARCH ESO INS FILT2 TYPE = 'FREE    ' / FILTi element
# HIERARCH ESO INS OPTI2 ID = 'open    ' / OPTIi unique ID
# HIERARCH ESO INS OPTI2 NAME = 'open    ' / OPTIi name
# HIERARCH ESO INS OPTI2 NO = 8 / OPTIi slot number
# HIERARCH ESO INS OPTI2 TYPE = 'FREE    ' / OPTIi element
# HIERARCH ESO INS OPTI3 ID = 'LF      ' / OPTIi unique ID
# HIERARCH ESO INS OPTI3 NAME = 'LF      ' / OPTIi name
# HIERARCH ESO INS OPTI3 NO = 4 / OPTIi slot number
# HIERARCH ESO INS OPTI3 TYPE = 'OBJECTIVE' / OPTIi element
# HIERARCH ESO DET FRAM NO = 1 / Frame number
# HIERARCH ESO DET FRAM UTC = '2014-12-22T07:54:39' / Time Recv Frame
# HIERARCH ESO DET EXP UTC = '2014-12-22T07:54:40' / File Creation Time
# HIERARCH ESO DET EXP NAME = 'name_J_0017' / Exposure Name
# HIERARCH ESO DET CHIP ID = 'ESO-Hawaii' / Detector ID
# HIERARCH ESO DET FILE CUBE ST = F / Data Cube On/Off
# HIERARCH ESO DET CON OPMODE = 'NORMAL  ' / Operational Mode
# HIERARCH ESO DET IRACE SEQCONT = F / Sequencer Cont. Mode
# HIERARCH ESO DET CHIP NAME = 'Hawaii  ' / Detector name
# HIERARCH ESO DET CHIP TYPE = 'IR      ' / The Type of Det Chip
# HIERARCH ESO DET CHIP NX = 1024 / Pixels in X
# HIERARCH ESO DET CHIP NY = 1024 / Pixels in Y
# HIERARCH ESO DET DIT = 20.0 / Integration Time
# HIERARCH ESO DET NCORRS = 2 / Read-Out Mode
# HIERARCH ESO DET NCORRS NAME = 'Double  ' / Read-Out Mode Name
# HIERARCH ESO DET MODE NAME = '' / DCS Detector Mode
# HIERARCH ESO DET DITDELAY = 0.0 / Pause Between DITs
# HIERARCH ESO DET NDIT = 5 / # of Sub-Integrations
# HIERARCH ESO DET NDITSKIP = 0 / DITs skipped at 1st.INT
# HIERARCH ESO DET CHOP NCYCLES = 4 / # of Chop Cycles
# HIERARCH ESO DET CHOP CYCSKIP = 0 / # of Chop Cycles to Skip
# HIERARCH ESO DET CHOP ST = F / Chopping On/Off
# HIERARCH ESO DET RSPEED = 4 / Read-Speed Factor
# HIERARCH ESO DET RSPEEDADD = 0 / Read-Speed Add
# HIERARCH ESO DET WIN TYPE = 0 / Win-Type: 0=SW/1=HW
# HIERARCH ESO DET WIN STARTX = 1.0 / Lower Left X Ref
# HIERARCH ESO DET WIN STARTY = 1.0 / Lower left Y Ref
# HIERARCH ESO DET WIN NX = 1024 / # of Pixels in X
# HIERARCH ESO DET WIN NY = 1024 / # of Pixels in Y
# HIERARCH ESO DET IRACE ADC1 NAME = 'ADC-G1  ' / Name for ADC Board
# HIERARCH ESO DET IRACE ADC1 HEADER = 0 / Header of ADC Board
# HIERARCH ESO DET IRACE ADC1 ENABLE = 1 / Enable ADC Board (0/1)
# HIERARCH ESO DET IRACE ADC1 FILTER1 = 1 / ADC Filter Adjustment
# HIERARCH ESO DET IRACE ADC1 FILTER2 = 0 / ADC Filter Adjustment
# HIERARCH ESO DET IRACE ADC1 DELAY = 7 / ADC Delay Adjustment
# HIERARCH ESO DET CHOP FREQ = 0.0 / Chopping Frequency
# HIERARCH ESO OCS WCS-RTD ST = T / Update RTD with WCS info.
# HIERARCH ESO OCS COMP ID = 'SW Version 33645 2000-03-04 01:28:56Z' / OS Soft
# HIERARCH ESO OCS DID = 'ESO-VLT-DIC.SOFI_OS-0.1' / Data dictionary for O
# HIERARCH ESO OCS SELECT-ARM = 'SW      ' / Detector arm
# HIERARCH ESO DET CHIP PXSPACE = 1.8E-05 / Pixel-Pixel Spacing
# CROSSTAL= 'True    '
# ILLUMCOR= 'illum_20140428_J_56778_1.fits' / illumination correction
# DIT     =                 20.0 / Integration Time
# NDIT    =                    5 / Number of sub-integrations
# PROV2   = 'SOFI.2014-12-22T07:54:42.549.fits' / Originating file
# TRACE2  = 'ASASSN-14ko_20141221_J_57621_2_sky.fits' / Originating file
# PROV3   = 'SOFI.2014-12-22T07:56:32.308.fits' / Originating file
# TRACE3  = 'ASASSN-14ko_20141221_J_57621_3_sky.fits' / Originating file
# PROV4   = 'SOFI.2014-12-22T07:58:22.187.fits' / Originating file
# TRACE4  = 'ASASSN-14ko_20141221_J_57621_4_sky.fits' / Originating file
# NTCRPIX1=                541.3 / reference x pixel of combined image
# NTCRPIX2=                541.7 / reference y pixel of combined image
# NUSTEP  =                    0 / Number of microstep positions
# NOFFSETS=                    4 / Number of offset positions
# NJITTER =                    1 / Number of microstep positions
# DATA_REL= 'SSDR3   '           / Data Release Version
# P3ORIG  = 'EDP     '           / ESO external data product

# %%
image_data = hdu_list[0].data
hdu_list.close()
del hdu_list

# %% [markdown]
# ### Display images

# %%
plt.figure(figsize=(5,5))
plt.imshow(image_data)
plt.colorbar()

# %% [markdown]
# ## Photometry Catalogue Exploration

# %%
photometry_filename = 'ADP.2017-08-24T13:14:25.964.fits'

hdu_list = fits.open(photometry_path + photometry_filename)
hdu_list.info()
# Out:
# Filename: ./data/PESSTO/Multi-epoch Photometry Catalogue/ADP.2017-08-24T13:14:25.964.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   ()
#   1  PHASE3CATALOG    1 BinTableHDU    315   2488R x 43C   [J, 50A, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
# Display PRIMARY HDU Info
hdu_list[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'ESO     '           / European Southern Observatory
# DATE    = '2017-08-21T15:21:05' / Date the file was written
# TELESCOP= 'ESO-NTT '           / Telescope
# INSTRUME= 'MULTI   '           / Instrument name
# INSTR1  = 'EFOSC   '           / Instrument name
# INSTR2  = 'SOFI    '           / Instrument name
# NOESODAT=                    T / True if non-ESO data used
# MJD-OBS =                56013 / Start of observations (days)
# MJD-END =                57534 / End of observations (days)
# PROG_ID = 'MULTI   '           / ESO programme identification
# PROGID1 = '188.D-3003'         / ESO programme identification
# PROGID2 = '191.D-0935'         / ESO programme identification
# OBSTECH = 'IMAGE   '           / Technique of observation
# PROCSOFT= 'MULTI   '           / Data reduction software/system with version no.
# PRODCATG= 'SCIENCE.CATALOG'    / Data product category
# REFERENC= '2015A&A...579A..40S' / Bibcode reference
# CHECKSUM= 'FcEPIZCPFbCPFZCP'   / HDU checksum updated 2017-08-25T13:32:55
# DATASUM = '0       '           / data unit checksum updated 2017-08-21T15:21:06
# ARCFILE = 'ADP.2017-08-24T13:14:25.964.fits' / Archive File Name
# ORIGFILE= 'PESSTO_MPHOT.fits'  / Original File Name
# P3ORIG  = 'EDP     '           / ESO external data product

# %%
# Display BINTABLE HDU Info
hdu_list[1].header
# Out:
# XTENSION= 'BINTABLE'           / FITS Extension first keyword
# BITPIX  =                    8 / Number of bits per data pixel
# NAXIS   =                    2 / Number of data axes
# NAXIS1  =                  218 / width of table in bytes
# NAXIS2  =                 2488 / number of rows in table
# PCOUNT  =                    0 / Parameter count
# GCOUNT  =                    1 / Group count
# TFIELDS =                   43 / number of columns
# EXTNAME = 'PHASE3CATALOG'      / FITS Extension name
# TTYPE1  = 'PHOT_ID '           / Label for field 1
# TFORM1  = 'J       '           / Data format of field 1
# TUNIT1  = '' / Physical unit of field 1
# TCOMM1  = 'Photometric Data Point ID (auto-increment)' / Description for field 1
# TUCD1   = 'meta.id;meta.main'  / Unified content descriptor of field 1
# TINDX1  =                    T / TRUE if database index exists for field 1
# TPRIC1  =                    T / TRUE if field 1 represents principal parameter
# TTYPE2  = 'SOURCE_ID'          / Label for field 2
# TFORM2  = '50A     '           / Data format of field 2
# TUNIT2  = '' / Physical unit of field 2
# TCOMM2  = 'PESSTO Source ID (catalogue data link)' / Description for field 2
# TUCD2   = 'meta.id '           / Unified content descriptor of field 2
# TINDX2  =                    T / TRUE if database index exists for field 2
# TXLNK2  = 'CATALOG '           / Data link type
# TXRGF2  = 'PESSTO_TRAN_CAT.fits' / Target catalogue
# TXCTY2  = 'TRANSIENT_ID'       / Data link catalogue's TTYPE
# TPRIC2  =                    T / TRUE if field 2 represents principal parameter
# TTYPE3  = 'MJD     '           / Label for field 3
# TFORM3  = 'E       '           / Data format of field 3
# TUNIT3  = 'days    '           / Physical unit of field 3
# TCOMM3  = 'Date of Observation' / Description for field 3
# TUCD3   = 'time.epoch'         / Unified content descriptor of field 3
# TINDX3  =                    T / TRUE if database index exists for field 3
# TPRIC3  =                    T / TRUE if field 3 represents principal parameter
# TTYPE4  = 'U_VEGA_MAG'         / Label for field 4
# TFORM4  = 'E       '           / Data format of field 4
# TUNIT4  = 'mag     '           / Physical unit of field 4
# TCOMM4  = 'U magnitude (VEGA)' / Description for field 4
# TUCD4   = 'phot.mag;em.opt.U'  / Unified content descriptor of field 4
# TINDX4  =                    0 / TRUE if database index exists for field 4
# TPRIC4  =                    T / TRUE if field 4 represents principal parameter
# TTYPE5  = 'U_VEGA_MAGERR'      / Label for field 5
# TFORM5  = 'E       '           / Data format of field 5
# TUNIT5  = 'mag     '           / Physical unit of field 5
# TCOMM5  = 'Error of U VEGA magnitude' / Description for field 5
# TUCD5   = 'stat.error;phot.mag;em.opt.U' / Unified content descriptor of field 5
# TINDX5  =                    0 / TRUE if database index exists for field 5
# TPRIC5  =                    0 / TRUE if field 5 represents principal parameter
# TTYPE6  = 'B_VEGA_MAG'         / Label for field 6
# TFORM6  = 'E       '           / Data format of field 6
# TUNIT6  = 'mag     '           / Physical unit of field 6
# TCOMM6  = 'B magnitude (VEGA)' / Description for field 6
# TUCD6   = 'phot.mag;em.opt.B'  / Unified content descriptor of field 6
# TINDX6  =                    0 / TRUE if database index exists for field 6
# TPRIC6  =                    T / TRUE if field 6 represents principal parameter
# TTYPE7  = 'B_VEGA_MAGERR'      / Label for field 7
# TFORM7  = 'E       '           / Data format of field 7
# TUNIT7  = 'mag     '           / Physical unit of field 7
# TCOMM7  = 'Error of B VEGA magnitude' / Description for field 7
# TUCD7   = 'stat.error;phot.mag;em.opt.B' / Unified content descriptor of field 7
# TINDX7  =                    0 / TRUE if database index exists for field 7
# TPRIC7  =                    0 / TRUE if field 7 represents principal parameter
# TTYPE8  = 'V_VEGA_MAG'         / Label for field 8
# TFORM8  = 'E       '           / Data format of field 8
# TUNIT8  = 'mag     '           / Physical unit of field 8
# TCOMM8  = 'V magnitude (VEGA)' / Description for field 8
# TUCD8   = 'phot.mag;em.opt.V'  / Unified content descriptor of field 8
# TINDX8  =                    0 / TRUE if database index exists for field 8
# TPRIC8  =                    T / TRUE if field 8 represents principal parameter
# TTYPE9  = 'V_VEGA_MAGERR'      / Label for field 9
# TFORM9  = 'E       '           / Data format of field 9
# TUNIT9  = 'mag     '           / Physical unit of field 9
# TCOMM9  = 'Error of V VEGA magnitude' / Description for field 9
# TUCD9   = 'stat.error;phot.mag;em.opt.V' / Unified content descriptor of field 9
# TINDX9  =                    0 / TRUE if database index exists for field 9
# TPRIC9  =                    0 / TRUE if field 9 represents principal parameter
# TTYPE10 = 'R_VEGA_MAG'         / Label for field 10
# TFORM10 = 'E       '           / Data format of field 10
# TUNIT10 = 'mag     '           / Physical unit of field 10
# TCOMM10 = 'R magnitude (VEGA)' / Description for field 10
# TUCD10  = 'phot.mag;em.opt.R'  / Unified content descriptor of field 10
# TINDX10 =                    0 / TRUE if database index exists for field 10
# TPRIC10 =                    T / TRUE if field 10 represents principal parameter
# TTYPE11 = 'R_VEGA_MAGERR'      / Label for field 11
# TFORM11 = 'E       '           / Data format of field 11
# TUNIT11 = 'mag     '           / Physical unit of field 11
# TCOMM11 = 'Error of R VEGA magnitude' / Description for field 11
# TUCD11  = 'stat.error;phot.mag;em.opt.R' / Unified content descriptor of field 1
# TINDX11 =                    0 / TRUE if database index exists for field 11
# TPRIC11 =                    0 / TRUE if field 11 represents principal parameter
# TTYPE12 = 'I_VEGA_MAG'         / Label for field 12
# TFORM12 = 'E       '           / Data format of field 12
# TUNIT12 = 'mag     '           / Physical unit of field 12
# TCOMM12 = 'I magnitude (VEGA)' / Description for field 12
# TUCD12  = 'phot.mag;em.opt.I'  / Unified content descriptor of field 12
# TINDX12 =                    0 / TRUE if database index exists for field 12
# TPRIC12 =                    T / TRUE if field 12 represents principal parameter
# TTYPE13 = 'I_VEGA_MAGERR'      / Label for field 13
# TFORM13 = 'E       '           / Data format of field 13
# TUNIT13 = 'mag     '           / Physical unit of field 13
# TCOMM13 = 'Error of I VEGA magnitude' / Description for field 13
# TUCD13  = 'stat.error;phot.mag;em.opt.I' / Unified content descriptor of field 1
# TINDX13 =                    0 / TRUE if database index exists for field 13
# TPRIC13 =                    0 / TRUE if field 13 represents principal parameter
# TTYPE14 = 'U_AB_MAG'           / Label for field 14
# TFORM14 = 'E       '           / Data format of field 14
# TUNIT14 = 'mag     '           / Physical unit of field 14
# TCOMM14 = 'u magnitude (AB)'   / Description for field 14
# TUCD14  = 'phot.mag;em.opt.U'  / Unified content descriptor of field 14
# TINDX14 =                    0 / TRUE if database index exists for field 14
# TPRIC14 =                    T / TRUE if field 14 represents principal parameter
# TTYPE15 = 'U_AB_MAGERR'        / Label for field 15
# TFORM15 = 'E       '           / Data format of field 15
# TUNIT15 = 'mag     '           / Physical unit of field 15
# TCOMM15 = 'Error of u AB magnitude' / Description for field 15
# TUCD15  = 'stat.error;phot.mag;em.opt.U' / Unified content descriptor of field 1
# TINDX15 =                    0 / TRUE if database index exists for field 15
# TPRIC15 =                    0 / TRUE if field 15 represents principal parameter
# TTYPE16 = 'G_AB_MAG'           / Label for field 16
# TFORM16 = 'E       '           / Data format of field 16
# TUNIT16 = 'mag     '           / Physical unit of field 16
# TCOMM16 = 'g magnitude (AB)'   / Description for field 16
# TUCD16  = 'phot.mag;em.opt.B'  / Unified content descriptor of field 16
# TINDX16 =                    0 / TRUE if database index exists for field 16
# TPRIC16 =                    T / TRUE if field 16 represents principal parameter
# TTYPE17 = 'G_AB_MAGERR'        / Label for field 17
# TFORM17 = 'E       '           / Data format of field 17
# TUNIT17 = 'mag     '           / Physical unit of field 17
# TCOMM17 = 'Error of g AB magnitude' / Description for field 17
# TUCD17  = 'stat.error;phot.mag;em.opt.B' / Unified content descriptor of field 1
# TINDX17 =                    0 / TRUE if database index exists for field 17
# TPRIC17 =                    0 / TRUE if field 17 represents principal parameter
# TTYPE18 = 'R_AB_MAG'           / Label for field 18
# TFORM18 = 'E       '           / Data format of field 18
# TUNIT18 = 'mag     '           / Physical unit of field 18
# TCOMM18 = 'r magnitude (AB)'   / Description for field 18
# TUCD18  = 'phot.mag;em.opt.R'  / Unified content descriptor of field 18
# TINDX18 =                    0 / TRUE if database index exists for field 18
# TPRIC18 =                    T / TRUE if field 18 represents principal parameter
# TTYPE19 = 'R_AB_MAGERR'        / Label for field 19
# TFORM19 = 'E       '           / Data format of field 19
# TUNIT19 = 'mag     '           / Physical unit of field 19
# TCOMM19 = 'Error of r AB magnitude' / Description for field 19
# TUCD19  = 'stat.error;phot.mag;em.opt.R' / Unified content descriptor of field 1
# TINDX19 =                    0 / TRUE if database index exists for field 19
# TPRIC19 =                    0 / TRUE if field 19 represents principal parameter
# TTYPE20 = 'I_AB_MAG'           / Label for field 20
# TFORM20 = 'E       '           / Data format of field 20
# TUNIT20 = 'mag     '           / Physical unit of field 20
# TCOMM20 = 'i magnitude (AB)'   / Description for field 20
# TUCD20  = 'phot.mag;em.opt.I'  / Unified content descriptor of field 20
# TINDX20 =                    0 / TRUE if database index exists for field 20
# TPRIC20 =                    T / TRUE if field 20 represents principal parameter
# TTYPE21 = 'I_AB_MAGERR'        / Label for field 21
# TFORM21 = 'E       '           / Data format of field 21
# TUNIT21 = 'mag     '           / Physical unit of field 21
# TCOMM21 = 'Error of i AB magnitude' / Description for field 21
# TUCD21  = 'stat.error;phot.mag;em.opt.I' / Unified content descriptor of field 2
# TINDX21 =                    0 / TRUE if database index exists for field 21
# TPRIC21 =                    0 / TRUE if field 21 represents principal parameter
# TTYPE22 = 'Z_AB_MAG'           / Label for field 22
# TFORM22 = 'E       '           / Data format of field 22
# TUNIT22 = 'mag     '           / Physical unit of field 22
# TCOMM22 = 'z magnitude (AB)'   / Description for field 22
# TUCD22  = 'phot.mag;em.opt.I'  / Unified content descriptor of field 22
# TINDX22 =                    0 / TRUE if database index exists for field 22
# TPRIC22 =                    T / TRUE if field 22 represents principal parameter
# TTYPE23 = 'Z_AB_MAGERR'        / Label for field 23
# TFORM23 = 'E       '           / Data format of field 23
# TUNIT23 = 'mag     '           / Physical unit of field 23
# TCOMM23 = 'Error of z AB magnitude' / Description for field 23
# TUCD23  = 'stat.error;phot.mag;em.opt.I' / Unified content descriptor of field 2
# TINDX23 =                    0 / TRUE if database index exists for field 23
# TPRIC23 =                    0 / TRUE if field 23 represents principal parameter
# TTYPE24 = 'J_VEGA_MAG'         / Label for field 24
# TFORM24 = 'E       '           / Data format of field 24
# TUNIT24 = 'mag     '           / Physical unit of field 24
# TCOMM24 = 'J magnitude (VEGA)' / Description for field 24
# TUCD24  = 'phot.mag;em.IR.J'   / Unified content descriptor of field 24
# TINDX24 =                    0 / TRUE if database index exists for field 24
# TPRIC24 =                    T / TRUE if field 24 represents principal parameter
# TTYPE25 = 'J_VEGA_MAGERR'      / Label for field 25
# TFORM25 = 'E       '           / Data format of field 25
# TUNIT25 = 'mag     '           / Physical unit of field 25
# TCOMM25 = 'Error of J VEGA magnitude' / Description for field 25
# TUCD25  = 'stat.error;phot.mag;em.IR.J' / Unified content descriptor of field 25
# TINDX25 =                    0 / TRUE if database index exists for field 25
# TPRIC25 =                    0 / TRUE if field 25 represents principal parameter
# TTYPE26 = 'H_VEGA_MAG'         / Label for field 26
# TFORM26 = 'E       '           / Data format of field 26
# TUNIT26 = 'mag     '           / Physical unit of field 26
# TCOMM26 = 'H magnitude (VEGA)' / Description for field 26
# TUCD26  = 'phot.mag;em.IR.H'   / Unified content descriptor of field 26
# TINDX26 =                    0 / TRUE if database index exists for field 26
# TPRIC26 =                    T / TRUE if field 26 represents principal parameter
# TTYPE27 = 'H_VEGA_MAGERR'      / Label for field 27
# TFORM27 = 'E       '           / Data format of field 27
# TUNIT27 = 'mag     '           / Physical unit of field 27
# TCOMM27 = 'Error of H VEGA magnitude' / Description for field 27
# TUCD27  = 'stat.error;phot.mag;em.IR.H' / Unified content descriptor of field 27
# TINDX27 =                    0 / TRUE if database index exists for field 27
# TPRIC27 =                    0 / TRUE if field 27 represents principal parameter
# TTYPE28 = 'KS_VEGA_MAG'        / Label for field 28
# TFORM28 = 'E       '           / Data format of field 28
# TUNIT28 = 'mag     '           / Physical unit of field 28
# TCOMM28 = 'KS magnitude (VEGA)' / Description for field 28
# TUCD28  = 'phot.mag;em.IR.K'   / Unified content descriptor of field 28
# TINDX28 =                    0 / TRUE if database index exists for field 28
# TPRIC28 =                    T / TRUE if field 28 represents principal parameter
# TTYPE29 = 'KS_VEGA_MAGERR'     / Label for field 29
# TFORM29 = 'E       '           / Data format of field 29
# TUNIT29 = 'mag     '           / Physical unit of field 29
# TCOMM29 = 'Error of KS VEGA magnitude' / Description for field 29
# TUCD29  = 'stat.error;phot.mag;em.IR.K' / Unified content descriptor of field 29
# TINDX29 =                    0 / TRUE if database index exists for field 29
# TPRIC29 =                    0 / TRUE if field 29 represents principal parameter
# TTYPE30 = 'LSQGR_AB_MAG'       / Label for field 30
# TFORM30 = 'E       '           / Data format of field 30
# TUNIT30 = 'mag     '           / Physical unit of field 30
# TCOMM30 = 'LSQgr magnitude (AB)' / Description for field 30
# TUCD30  = 'phot.mag;em.opt.V'  / Unified content descriptor of field 30
# TINDX30 =                    0 / TRUE if database index exists for field 30
# TPRIC30 =                    T / TRUE if field 30 represents principal parameter
# TTYPE31 = 'LSQGR_AB_MAGERR'    / Label for field 31
# TFORM31 = 'E       '           / Data format of field 31
# TUNIT31 = 'mag     '           / Physical unit of field 31
# TCOMM31 = 'Error of LSQgr AB magnitude' / Description for field 31
# TUCD31  = 'stat.error;phot.mag;em.opt.V' / Unified content descriptor of field 3
# TINDX31 =                    0 / TRUE if database index exists for field 31
# TPRIC31 =                    0 / TRUE if field 31 represents principal parameter
# TTYPE32 = 'UVW2_SWIFT_MAG'     / Label for field 32
# TFORM32 = 'E       '           / Data format of field 32
# TUNIT32 = 'mag     '           / Physical unit of field 32
# TCOMM32 = 'uvw2 magnitude (SWIFT)' / Description for field 32
# TUCD32  = 'phot.mag;em.UV'     / Unified content descriptor of field 32
# TINDX32 =                    0 / TRUE if database index exists for field 32
# TPRIC32 =                    T / TRUE if field 32 represents principal parameter
# TTYPE33 = 'UVW2_SWIFT_MAGERR'  / Label for field 33
# TFORM33 = 'E       '           / Data format of field 33
# TUNIT33 = 'mag     '           / Physical unit of field 33
# TCOMM33 = 'Error of uvw2 SWIFT magnitude' / Description for field 33
# TUCD33  = 'stat.error;phot.mag;em.UV' / Unified content descriptor of field 33
# TINDX33 =                    0 / TRUE if database index exists for field 33
# TPRIC33 =                    0 / TRUE if field 33 represents principal parameter
# TTYPE34 = 'UVM2_SWIFT_MAG'     / Label for field 34
# TFORM34 = 'E       '           / Data format of field 34
# TUNIT34 = 'mag     '           / Physical unit of field 34
# TCOMM34 = 'uvm2 magnitude (SWIFT)' / Description for field 34
# TUCD34  = 'phot.mag;em.UV'     / Unified content descriptor of field 34
# TINDX34 =                    0 / TRUE if database index exists for field 34
# TPRIC34 =                    T / TRUE if field 34 represents principal parameter
# TTYPE35 = 'UVM2_SWIFT_MAGERR'  / Label for field 35
# TFORM35 = 'E       '           / Data format of field 35
# TUNIT35 = 'mag     '           / Physical unit of field 35
# TCOMM35 = 'Error of uvm2 SWIFT magnitude' / Description for field 35
# TUCD35  = 'stat.error;phot.mag;em.UV' / Unified content descriptor of field 35
# TINDX35 =                    0 / TRUE if database index exists for field 35
# TPRIC35 =                    0 / TRUE if field 35 represents principal parameter
# TTYPE36 = 'UVW1_SWIFT_MAG'     / Label for field 36
# TFORM36 = 'E       '           / Data format of field 36
# TUNIT36 = 'mag     '           / Physical unit of field 36
# TCOMM36 = 'uvw1 magnitude (SWIFT)' / Description for field 36
# TUCD36  = 'phot.mag;em.UV'     / Unified content descriptor of field 36
# TINDX36 =                    0 / TRUE if database index exists for field 36
# TPRIC36 =                    T / TRUE if field 36 represents principal parameter
# TTYPE37 = 'UVW1_SWIFT_MAGERR'  / Label for field 37
# TFORM37 = 'E       '           / Data format of field 37
# TUNIT37 = 'mag     '           / Physical unit of field 37
# TCOMM37 = 'Error of uvw1 SWIFT magnitude' / Description for field 37
# TUCD37  = 'stat.error;phot.mag;em.UV' / Unified content descriptor of field 37
# TINDX37 =                    0 / TRUE if database index exists for field 37
# TPRIC37 =                    0 / TRUE if field 37 represents principal parameter
# TTYPE38 = 'U_SWIFT_MAG'        / Label for field 38
# TFORM38 = 'E       '           / Data format of field 38
# TUNIT38 = 'mag     '           / Physical unit of field 38
# TCOMM38 = 'u magnitude (SWIFT)' / Description for field 38
# TUCD38  = 'phot.mag;em.opt.U'  / Unified content descriptor of field 38
# TINDX38 =                    0 / TRUE if database index exists for field 38
# TPRIC38 =                    T / TRUE if field 38 represents principal parameter
# TTYPE39 = 'U_SWIFT_MAGERR'     / Label for field 39
# TFORM39 = 'E       '           / Data format of field 39
# TUNIT39 = 'mag     '           / Physical unit of field 39
# TCOMM39 = 'Error of u SWIFT magnitude' / Description for field 39
# TUCD39  = 'stat.error;phot.mag;em.opt.U' / Unified content descriptor of field 3
# TINDX39 =                    0 / TRUE if database index exists for field 39
# TPRIC39 =                    0 / TRUE if field 39 represents principal parameter
# TTYPE40 = 'B_SWIFT_MAG'        / Label for field 40
# TFORM40 = 'E       '           / Data format of field 40
# TUNIT40 = 'mag     '           / Physical unit of field 40
# TCOMM40 = 'b magnitude (SWIFT)' / Description for field 40
# TUCD40  = 'phot.mag;em.opt.B'  / Unified content descriptor of field 40
# TINDX40 =                    0 / TRUE if database index exists for field 40
# TPRIC40 =                    T / TRUE if field 40 represents principal parameter
# TTYPE41 = 'B_SWIFT_MAGERR'     / Label for field 41
# TFORM41 = 'E       '           / Data format of field 41
# TUNIT41 = 'mag     '           / Physical unit of field 41
# TCOMM41 = 'Error of b SWIFT magnitude' / Description for field 41
# TUCD41  = 'stat.error;phot.mag;em.opt.B' / Unified content descriptor of field 4
# TINDX41 =                    0 / TRUE if database index exists for field 41
# TPRIC41 =                    0 / TRUE if field 41 represents principal parameter
# TTYPE42 = 'V_SWIFT_MAG'        / Label for field 42
# TFORM42 = 'E       '           / Data format of field 42
# TUNIT42 = 'mag     '           / Physical unit of field 42
# TCOMM42 = 'v magnitude (SWIFT)' / Description for field 42
# TUCD42  = 'phot.mag;em.opt.V'  / Unified content descriptor of field 42
# TINDX42 =                    0 / TRUE if database index exists for field 42
# TPRIC42 =                    T / TRUE if field 42 represents principal parameter
# TTYPE43 = 'V_SWIFT_MAGERR'     / Label for field 43
# TFORM43 = 'E       '           / Data format of field 43
# TUNIT43 = 'mag     '           / Physical unit of field 43
# TCOMM43 = 'Error of v SWIFT magnitude' / Description for field 43
# TUCD43  = 'stat.error;phot.mag;em.opt.V' / Unified content descriptor of field 4
# TINDX43 =                    0 / TRUE if database index exists for field 43
# TPRIC43 =                    0 / TRUE if field 43 represents principal parameter
# CHECKSUM= 'Mb3FNZ1FMa1FMY1F'   / HDU checksum updated 2017-08-21T15:21:06
# DATASUM = '672369605'          / data unit checksum updated 2017-08-21T15:21:06

# %% [markdown]
# Likewise, this catalog contains two headers where the first is the file metadata, and the second is a binary table with the contents of the catalogue.

# %%
# Transform Catalogue to Pandas
spectral_df = Table(hdu_list[1].data).to_pandas()
# Close HDU file
hdu_list.close()

# %% [markdown]
# #### Sample Catalogue row

# %%
transient_df.iloc[0]
# Out:
# TRANSIENT_ID                                                   SN2013U
# TRANSIENT_DISCOVERY_ID                             PSNJ100112000019423
# TRANSIENT_RAJ2000                                                150.3
# TRANSIENT_DECJ2000                                            0.328417
# TRANSIENT_CLASSIFICATION                                         SN Ia
# TRANSIENT_CLASSIFICATION_PECULIAR_FLAG                               1
# TRANSIENT_CLASSIFICATION_SOURCE                              CBET 3410
# TRANSIENT_CLASSIFICATION_ATEL                                        0
# TRANSIENT_CLASSIFICATION_MJD                                     56329
# TRANSIENT_CLASSIFICATION_REDSHIFT                              0.03451
# TRANSIENT_CLASSIFICATION_PHASE                                 pre-max
# TRANSIENT_CLASSIFICATION_PHASE_DAYS_LOWER_LIMIT                     -7
# TRANSIENT_CLASSIFICATION_PHASE_DAYS_UPPER_LIMIT                     -4
# TRANSIENT_DISCOVERY_MJD                                          56297
# TRANSIENT_DISCOVERY_MAG                                           16.6
# TRANSIENT_DISCOVERY_MAG_FILTER                              unfiltered
# FOLLOWUP_TARGET                                                      1
# HOST_SEARCH_STAGE                                                    1
# HOST_ID                                                   CGCG 008-023
# HOST_RAJ2000                                                   150.299
# HOST_DECJ2000                                                  0.32934
# HOST_OFFSET_N                                                  -0.0009
# HOST_OFFSET_E                                                   0.0005
# HOST_REDSHIFT_SPEC_SOURCE                                          NED
# HOST_REDSHIFT_SPEC                                            0.034506
# HOST_REDSHIFT_PHOT_SOURCE                                         SDSS
# HOST_REDSHIFT_PHOT                                              0.0831
# HOST_REDSHIFT_PHOT_ERR                                           0.026
# TRANSIENT_IAU_ID                                               SN2013U
# TRANSIENT_ALTERNATIVE_IDS                                         NULL
# Name: 0, dtype: object

# %% [markdown]
# #### Count number of NaNs per column

# %%
# Proportion of null values per column
total = transient_df.isnull().sum()
proportion = transient_df.isnull().sum() / len(transient_df)*100
pd.concat([total, proportion], axis=1, keys= ['Total', 'Percentage'])
# Out:
#                                                  Total  Percentage
# TRANSIENT_ID                                         0    0.000000
# TRANSIENT_DISCOVERY_ID                               0    0.000000
# TRANSIENT_RAJ2000                                    0    0.000000
# TRANSIENT_DECJ2000                                   0    0.000000
# TRANSIENT_CLASSIFICATION                             0    0.000000
# TRANSIENT_CLASSIFICATION_PECULIAR_FLAG               0    0.000000
# TRANSIENT_CLASSIFICATION_SOURCE                      0    0.000000
# TRANSIENT_CLASSIFICATION_ATEL                        0    0.000000
# TRANSIENT_CLASSIFICATION_MJD                         0    0.000000
# TRANSIENT_CLASSIFICATION_REDSHIFT                   45    4.347826
# TRANSIENT_CLASSIFICATION_PHASE                       0    0.000000
# TRANSIENT_CLASSIFICATION_PHASE_DAYS_LOWER_LIMIT      0    0.000000
# TRANSIENT_CLASSIFICATION_PHASE_DAYS_UPPER_LIMIT      0    0.000000
# TRANSIENT_DISCOVERY_MJD                              0    0.000000
# TRANSIENT_DISCOVERY_MAG                              0    0.000000
# TRANSIENT_DISCOVERY_MAG_FILTER                       0    0.000000
# FOLLOWUP_TARGET                                      0    0.000000
# HOST_SEARCH_STAGE                                    0    0.000000
# HOST_ID                                              0    0.000000
# HOST_RAJ2000                                       210   20.289855
# HOST_DECJ2000                                      210   20.289855
# HOST_OFFSET_N                                      210   20.289855
# HOST_OFFSET_E                                      210   20.289855
# HOST_REDSHIFT_SPEC_SOURCE                            0    0.000000
# HOST_REDSHIFT_SPEC                                 703   67.922705
# HOST_REDSHIFT_PHOT_SOURCE                            0    0.000000
# HOST_REDSHIFT_PHOT                                 805   77.777778
# HOST_REDSHIFT_PHOT_ERR                             805   77.777778
# TRANSIENT_IAU_ID                                     0    0.000000
# TRANSIENT_ALTERNATIVE_IDS                            0    0.000000

# %% [markdown]
# ## Spectral Data Exploration

# %%
sample_spectral_filename_binary = 'ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_sb.fits'

# Sample 
# sample_spectral_filename_1d = 'ASASSN-14ko_20141211_Gr16_OG530_slit1.0_57595_1_sb'

# Different slit
# sample_spectral_filename_1d = 'ASASSN-14ko_20141211_Gr16_OG530_slit1.0_57595_1_sb'

# Others: grism, filter, slit width

# %%
# Display PRIMARY HDU Info
hdu_list = fits.open(spectral_path + sample_spectral_filename_binary)
hdu_list.info()
# Out:
# Filename: ./data/PESSTO/Spectral Data/ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_sb.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     281   ()
#   1  PHASE3BINTABLE    1 BinTableHDU     46   1R x 4C   [1011E, 1011E, 1011E, 1011E]

# %%
hdu_list[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# ORIGIN  = 'ESO     '           / European Southern Observatory
# IRAF-TLM= '2016-07-26T14:27:39' / Time of last modification
# DATE    = '2016-07-26T14:27:27' / UT date when this file was written
# TELESCOP= 'ESO-NTT '           / ESO Telescope Name
# INSTRUME= 'EFOSC   '           / Instrument used.
# OBJECT  = 'ASASSN-14ko'        / Original target.
# RA      =        81.3255416667 / 05:25:18.13 RA (J2000) pointing (deg)
# DEC     =            -46.00565 / -46:00:20.3 DEC (J2000) pointing (deg)
# EQUINOX =                 2000 / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# EXPTIME =            1500.0148 / Total integration time
# MJD-OBS =        57003.3264101 / MJD start (2014-12-12 07:50:01.832628)
# DATE-OBS= '2014-12-12T07:50:01' / Date of observation
# UTC     =                28194 / 06:42:14.000 UTC at start (sec)
# LST     =            30642.773 / 15:29:43.586 LST at start (sec)
# PI-COI  = 'Smartt  '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# HIERARCH ESO ADA ABSROT END = 213.86364 / Abs rot angle at exp end (deg)
# HIERARCH ESO ADA ABSROT START = 214.56656 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA GUID DEC = -45.87938 / -45:52:45.7 Guide Star DEC J2000
# HIERARCH ESO ADA GUID RA = 81.61060999999999 / 05:26:26.54 Guide Star RA J2000
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 169.554 / Position angle at start
# HIERARCH ESO DET BITS =     16 / Bits per pixel readout
# HIERARCH ESO DET CHIP1 DATE = '2000-08-30' / Date of installation [YYYY-MM-DD]
# HIERARCH ESO DET CHIP1 ID = 'ccd40   ' / Detector chip identification
# HIERARCH ESO DET CHIP1 INDEX = 1 / Chip index
# HIERARCH ESO DET CHIP1 NAME = 'LORAL   ' / Detector chip name
# HIERARCH ESO DET CHIP1 NX = 2048 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY = 2048 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX = 15 / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY = 15 / Size of pixel in Y
# HIERARCH ESO DET CHIP1 X =   1 / X location in array
# HIERARCH ESO DET CHIP1 XGAP = 0 / Gap between chips along x
# HIERARCH ESO DET CHIP1 Y =   1 / Y location in array
# HIERARCH ESO DET CHIP1 YGAP = 0 / Gap between chips along y
# HIERARCH ESO DET CHIPS =     1 / # of chips in detector array
# HIERARCH ESO DET DATE = '2000-08-30' / Installation date
# HIERARCH ESO DET DEC =       0 / Apparent 00:00:00.0 DEC at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET EXP NO =  151 / Unique exposure ID number
# HIERARCH ESO DET EXP RDTTIME = 22.39 / image readout time
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP XFERTIM = 22.326 / image transfer time
# HIERARCH ESO DET FRAM ID =   1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET ID = 'CCD FIERA - Rev: 3.96' / Detector system Id
# HIERARCH ESO DET NAME = 'efosc - ccdefosc' / Name of detector system
# HIERARCH ESO DET OUT1 CHIP = 1 / Chip to which the output belongs
# HIERARCH ESO DET OUT1 CONAD = 1.1 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 ID = 'L       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 INDEX = 1 / Output index
# HIERARCH ESO DET OUT1 NAME = 'L       ' / Description of output
# HIERARCH ESO DET OUT1 NX = 1024 / valid pixels along X
# HIERARCH ESO DET OUT1 NY = 1024 / valid pixels along Y
# HIERARCH ESO DET OUT1 OVSCX = 0 / Overscan region in X
# HIERARCH ESO DET OUT1 OVSCY = 6 / Overscan region in Y
# HIERARCH ESO DET OUT1 PRSCX = 6 / Prescan region in X
# HIERARCH ESO DET OUT1 PRSCY = 0 / Prescan region in Y
# HIERARCH ESO DET OUT1 X = 2048 / X location of output
# HIERARCH ESO DET OUT1 Y =    1 / Y location of output
# HIERARCH ESO DET OUTPUTS =   1 / # of outputs
# HIERARCH ESO DET OUTREF =    0 / reference output
# HIERARCH ESO DET RA =        0 / Apparent 00:00:00.0 RA at start
# HIERARCH ESO DET READ CLOCK = 'read L port Fast' / Readout clock pattern used
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ NFRAM = 1 / Number of readouts buffered in sin
# HIERARCH ESO DET READ SPEED = 'fastL   ' / Readout speed
# HIERARCH ESO DET SHUT ID = 'ccd shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMCLOS = 0.079 / Time taken to close shutter
# HIERARCH ESO DET SHUT TMOPEN = 0.05 / Time taken to open shutter
# HIERARCH ESO DET SHUT TYPE = 'Slit    ' / type of shutter
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET TELE INT = '        ' / Interval between two successive te
# HIERARCH ESO DET TELE NO = '        ' / # of sources active
# HIERARCH ESO DET TLM1 END = '        ' / Telemetry value at read completion
# HIERARCH ESO DET TLM1 ID = '        ' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 NAME = '        ' / Description of telemetry param.
# HIERARCH ESO DET TLM1 START = '        ' / Telemetry value at read start
# HIERARCH ESO DET TLM2 END = '        ' / Telemetry value at read completion
# HIERARCH ESO DET TLM2 ID = '        ' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 NAME = '        ' / Description of telemetry param.
# HIERARCH ESO DET TLM2 START = '        ' / Telemetry value at read start
# HIERARCH ESO DET TLM3 END = '        ' / Telemetry value at read completion
# HIERARCH ESO DET TLM3 ID = '        ' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 NAME = '        ' / Description of telemetry param.
# HIERARCH ESO DET TLM3 START = '        ' / Telemetry value at read start
# HIERARCH ESO DET TLM4 END = '        ' / Telemetry value at read completion
# HIERARCH ESO DET TLM4 ID = '        ' / ID of telemetry sens
# HIERARCH ESO DET TLM4 NAME = '        ' / Description of telemetry param.
# HIERARCH ESO DET TLM4 START = '        ' / Telemetry value at read start
# HIERARCH ESO DET TLM5 END = '        ' / Telemetry value at read completion
# HIERARCH ESO DET TLM5 ID = '        ' / ID of telemetry sens
# HIERARCH ESO DET TLM5 NAME = '        ' / Description of telemetry param.
# HIERARCH ESO DET TLM5 START = '        ' / Telemetry value at read start
# HIERARCH ESO DET TLM6 END = '        ' / Telemetry value at read completion
# HIERARCH ESO DET TLM6 ID = '        ' / ID of telemetry senso
# HIERARCH ESO DET TLM6 NAME = '        ' / Description of telemetry param.
# HIERARCH ESO DET TLM6 START = '        ' / Telemetry value at read start
# HIERARCH ESO DET WIN1 BINX = 2 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 2 / Binning factor along Y
# HIERARCH ESO DET WIN1 DIT1 = 1500.014763 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 1500.0884 / Dark current time
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 NX = 1030 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 1030 / # of pixels along Y
# HIERARCH ESO DET WIN1 ST =   T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 UIT1 = 1500 / user defined subintegration time
# HIERARCH ESO DET WINDOWS =   1 / # of windows readout
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-d
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.EFOSC_ICS-175958' / Data dictionary
# HIERARCH ESO INS DPOR POS = 0.0 / Position move
# HIERARCH ESO INS DPOR ST =   F / Instrument depolarizer rotating.
# HIERARCH ESO INS FILT1 ID = 'F1      ' / Filter unique id.
# HIERARCH ESO INS FILT1 NAME = 'Free    ' / Filter name.
# HIERARCH ESO INS FILT1 NO =  1 / Filter wheel position index.
# HIERARCH ESO INS GRIS1 ID = 'F7      ' / OPTIi unique ID.
# HIERARCH ESO INS GRIS1 NAME = 'Gr#11   ' / OPTIi name.
# HIERARCH ESO INS GRIS1 NO =  7 / OPTIi slot number.
# HIERARCH ESO INS GRIS1 TYPE = 'FILTER  ' / OPTIi element.
# HIERARCH ESO INS ID = 'EFOSC/1.57' / Instrument ID.
# HIERARCH ESO INS MODE = 'DEFAULT ' / Instrument mode used.
# HIERARCH ESO INS SLIT1 ENC = 257949 / Slit absolute position [Enc].
# HIERARCH ESO INS SLIT1 LEN = 0.0 / SLIT length [arcsec].
# HIERARCH ESO INS SLIT1 NAME = 'slit#1.0' / Slit common name.
# HIERARCH ESO INS SLIT1 NO =  5 / Slide position.
# HIERARCH ESO INS SLIT1 WID = 0 / SLIT width [arcsec].
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS WP NAME = 'HALF    ' / WP name, valid values are HALF/QUA
# HIERARCH ESO INS WP ST = 'OUT     ' / WP position.
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-1.11' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 3614 / Expected execution time
# HIERARCH ESO OBS GRP =       0 / linked blocks
# HIERARCH ESO OBS ID = 100364351 / Observation block ID
# HIERARCH ESO OBS NAME = 'ASASSN-14ko_Spec_V_16_0__17_5_g1' / OB name
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 2931 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '191.D-0935(I)' / ESO program identification
# HIERARCH ESO OBS START = '2014-12-12T07:40:55' / OB start time
# HIERARCH ESO OBS TARG NAME = 'ASASSN-14ko' / OB target name
# HIERARCH ESO OBS TPLNO =     2 / Template number within OB
# HIERARCH ESO OCS CON WCSFITS = T / Setup OS to add WCS in fits  .
# HIERARCH ESO OCS DET1 IMGNAME = 'EFOSC_Spectrum' / Data File Name.
# HIERARCH ESO TEL AIRM END = 1.389 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.296 / Airmass at start
# HIERARCH ESO TEL ALT = 50.436 / Alt angle at start (deg)
# HIERARCH ESO TEL AMBI FWHM END = 0.37 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI FWHM START = 0.41 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI PRES END = 769.6 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI PRES START = 769.6 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI RHUM = 29 / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP = 13.45 / Observatory ambient temperature qu
# HIERARCH ESO TEL AMBI WINDDIR = 28 / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI WINDSP = 2.9 / Observatory ambient wind speed que
# HIERARCH ESO TEL AZ = 51.948 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL CHOP ST =   F / True when chopping is active
# HIERARCH ESO TEL DATE = '2009-06-05T01:00:00' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL FOCU ID = 'NB      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 38.501 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE = 5.36 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE = -3.32 / M2 setting (mm)
# HIERARCH ESO TEL GEOELEV = 2377 / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT = -29.2584 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON = -70.7345 / Tel geo longitude (+=East) (deg)
# HIERARCH ESO TEL ID = 'v 254740' / TCS version number
# HIERARCH ESO TEL MOON DEC = 9.613799999999999 / +09:36:49.6 DEC (J2000) (deg)
# HIERARCH ESO TEL MOON RA = 147.450867 / 09:49:48.20 RA (J2000) (deg)
# HIERARCH ESO TEL OPER = 'I. CONDOR' / Telescope Operator
# HIERARCH ESO TEL PARANG END = 86.577 / Parallactic angle at end (deg)
# HIERARCH ESO TEL PARANG START = 81.455 / Parallactic angle at start (deg)
# HIERARCH ESO TEL TARG ALPHA = 52518.13 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL TARG DELTA = -460020.0 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000 / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (default J=Julian)
# HIERARCH ESO TEL TARG EQUINOX = 2000 / Equinox
# HIERARCH ESO TEL TARG PARALLAX = 0 / Parallax
# HIERARCH ESO TEL TARG PMA = 0.0 / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0.0 / Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL = 0 / Radial velocity
# HIERARCH ESO TEL TH M1 TEMP = -1 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL TSS TEMP8 = 11.66 / Temperature Sensing System
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO =     1 / Exposure number within template
# HIERARCH ESO TPL ID = 'EFOSC_spec_obs_Spectrum' / Template signature ID
# HIERARCH ESO TPL NAME = 'Spectroscopy' / Template name
# HIERARCH ESO TPL NEXP =      1 / Number of exposures within templat
# HIERARCH ESO TPL PRESEQ = 'EFOSC_spec_obs_Spectrum.seq' / Sequencer script
# HIERARCH ESO TPL START = '2014-12-12T07:49:36' / TPL start time
# HIERARCH ESO TPL VERSION = '1.0     ' / Version of the template
# ORIGFILE= 'ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_sb.fits' / Original Fi
# ARCFILE = 'ADP.2016-11-17T12:50:58.763.fits' / Archive File Name
# CHECKSUM= 'Uca7abY5Wba5abY5'   / HDU checksum updated 2017-08-30T17:18:19
# DATASUM = '0       '           / data unit checksum updated 2016-08-30T15:57:01
# WCSDIM  =                    3
# LTM1_1  =                    1
# LTM2_2  =                    1
# WAT0_001= 'system=equispec'
# WAT1_001= 'wtype=linear label=Wavelength units=angstroms'
# WAT2_001= 'wtype=linear'
# TRIM    = 'Jul 26 15:54 Trim data section is [100:950,5:1015]'
# ZEROCOR = 'bias_20141212_Gr11_Free_57595.fits'
# CCDSEC  = '[100:950,5:1015]'
# BIASSEC = '[1:851,1:1011]'
# CCDMEAN =             147.6572
# CCDMEANT=           1154015695
# CCDPROC = 'Jul 26 15:54 CCD processing done'
# FLATCOR = 'nflat_20141211_Gr11_Free_slit1.0_100364358_57595.fits'
# PROV1   = 'EFOSC.2014-12-12T07:50:01.834.fits' / Originating file
# SINGLEXP=                    T / TRUE if resulting from single exposure
# M_EPOCH =                    F / TRUE if resulting from multiple epochs
# FILETYPE=                22210 / pre-reduced image
# NCOMBINE=                    1 / Number of raw science data
# TRACE1  = 'tASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_f.fits' / Originating
# AIRMASS =             1.341103 / mean airmass computed with astcalc
# LACOSMIC=                    T / TRUE if Laplacian cosmic ray rejection has been
# FLUXCAL = 'ABSOLUTE'           / Type of flux calibration
# HIERARCH ESO DET OUT1 GAIN = 1.18 / Conversion from electrons to ADU
# HIERARCH ESO DET OUT1 RON = 11.6 / Readout noise per output (e-)
# EFFRON  =        12.9455924405 / Effective readout noise per output (e-)
# PROG_ID = '191.D-0935(I)'      / ESO program identification
# OBSTECH = 'SPECTRUM'           / Observation technique
# REFERENC= 'Smartt et al 2014'  / Bibliographic reference
# PROCSOFT= 'ntt_2.2.8'          / pipeline version
# OBID1   =            100364351 / Observation block ID
# DETRON  =                 11.6 / Readout noise per output (e-)
# GAIN    =                 1.18 / Conversion from electrons to ADU
# PRODCATG= 'SCIENCE.SPECTRUM'   / Data product category
# MJD-END =        57003.3437714 / MJD-END = MJD-OBS + JD(exptime)
# QUALITY = 'Final   '           / Final or Fast reduction
# TEXPTIME=            1500.0148 / Total integ. time of all exposure
# HIERARCH ESO INS MOS1 LEN = 1777 / MOSi slit length [arcsec]
# HIERARCH ESO INS MOS1 POSX = 1002 / MOSi slit position [pix]
# HIERARCH ESO INS MOS1 POSY = 997 / MOSi slit position [pix]
# DCLOG1  = 'Transform'
# DC-FLAG =                    0
# SPEC_RES=        399.687626026 / Spectral resolving power
# ARC     = 'arc_ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1.fits'
# SHIFT   =                 10.2
# WAVELMIN=        334.457229996 / [nm] Minimum wavelength
# LAMRMS  =                0.013 / residual RMS [nm]
# SPEC_SYE=                  1.0 / systematic error
# WAVELMAX=        746.699360275 / [nm] Maximum wavelength
# SPEC_ERR=     0.00459619407771 / statistical uncertainty
# LAMNLIN =                    8 / Nb of arc lines used in the fit of the wavel. s
# SPEC_BIN=               0.4082 / average spectral coordinate bin size [nm/pix]
# FLUXERR =                 15.2 / Fractional uncertainty of the flux [%]
# EXT_OBJ =                    F / TRUE if extened
# DISPELEM= 'Gr#11   '           / Dispersive element name
# SPECSYS = 'TOPOCENT'           / Observed frame
# CONTNORM=                    F / TRUE if normalised to the continuum
# TOT_FLUX=                    F / TRUE if phot. cond. and all src flux is capture
# SENSFUN = 'sens_20141211_Gr11_Free_gd71_57595_1.fits'
# ASSON1  = 'ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_si.fits' / Name of ass
# XMAX    =        7466.99360275 / [A]  maximum wavelength
# XMIN    =        3344.57229996 / [A] minimum wavelength
# APNUM1  = '1 1 440.05 445.57'
# LTM3_3  =                    1
# WAT3_001= 'wtype=linear'
# EX-FLAG =                    0
# CA-FLAG =                    0
# SNR     =        50.8365478516 / Average signal to noise ratio per pixel
# BANDID1 = 'spectrum - background fit, weights variance, clean yes'
# BANDID2 = 'raw - background fit, weights none, clean no'
# BANDID3 = 'background - background fit'
# BANDID4 = 'sigma - background fit, weights variance, clean yes'
# ATMOFILE= 'atmo_tgd71_20141211_Gr11_Free_slit1.0_57595_1_ex.fits'
# DATA_REL= 'SSDR3   '           / Data Release Version
# P3ORIG  = 'EDP     '           / ESO external data product
# HDRVER  = '2017-01-08T15:45:05.556' / Header timetag
# COMMENT processed by HOTF_version : 1.1 on 2017-08-30T17:18:19

# %%
hdu_list[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                16176 / Length of data axis 1
# NAXIS2  =                    1 / Axis length
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    4 / number of table fields
# OBJECT  = 'ASASSN-14ko'        / Original target.
# RA      =        81.3255416667 / 05:25:18.13 RA (J2000) pointing (deg)
# DEC     =            -46.00565 / -46:00:20.3 DEC (J2000) pointing (deg)
# CHECKSUM= 'ChdcFgcZCgcaCgcY'   / HDU checksum updated 2017-08-30T17:18:19
# DATASUM = '3007086606'         / data unit checksum updated 2016-08-30T15:57:01
# VOCLASS = 'SPECTRUM V1.0'      / VO Data Model
# SPEC_BW =         412.24213028 / [nm] Bandpass Width Wmax - Wmin
# VOPUB   = 'ESO/SAF '           / VO Publishing Authority
# APERTURE=            0.0002778 / [deg] Aperture diameter
# SPEC_VAL=        540.578295135 / [nm] Mean Wavelength
# TELAPSE =            1500.0148 / Total elapsed time [s]
# TITLE   = 'ASASSN-14ko'        / Dataset title
# TMID    =        57003.3350908 / [d] MJD mid exposure
# TTYPE1  = 'WAVE    '           / Label for field 1
# TUTYP1  = 'Spectrum.Data.SpectralAxis.Value'
# TUNIT1  = 'angstrom'           / Physical unit of field 1
# TUCD1   = 'em.wl;obs.atmos'    / em.wl: vacuum, em.wl;obs.atmos: air
# TDMIN1  =        3344.57229996 / Start in spectral coord.
# TDMAX1  =        7466.99360275 / Start in spectral coord.
# TTYPE2  = 'FLUX    '           / Label for field 2
# TUTYP2  = 'Spectrum.Data.FluxAxis.Value'
# TUNIT2  = 'erg cm**(-2) s**(-1) angstrom**(-1)' / Physical unit of field 2
# TUCD2   = 'phot.flux.density;em.wl;src.net;meta.main' / UCD of field2
# TTYPE3  = 'ERR     '           / Label for field 3
# TUTYP3  = 'Spectrum.Data.FluxAxis.Accuracy.StatError'
# TUNIT3  = 'erg cm**(-2) s**(-1) angstrom**(-1)' / Physical unit of field 3
# TUCD3   = 'stat.error;phot.flux.density;meta.main' / UCD of field3
# TTYPE4  = 'SKYBACK '           / Label for field 4
# TUTYP4  = 'Spectrum.Data.BackgroundModel.Value'
# TUNIT4  = 'erg cm**(-2) s**(-1) angstrom**(-1)' / Physical unit of field 4
# TUCD4   = 'phot.flux.density;em.wl' / UCD of field4
# EXTNAME = 'PHASE3BINTABLE'     / FITS Extension name
# INHERIT =                    T / Primary header keywords are inherited
# NELEM   =                 1011 / Length of the data arrays
# TFORM1  = '1011E   '           / Data format of field 1
# TFORM2  = '1011E   '           / Data format of field 2
# TFORM3  = '1011E   '           / Data format of field 3
# TFORM4  = '1011E   '           / Data format of field 4

# %%
spectral_data = hdu_list[1].data

# %%
hdu_list.close()

# %% [markdown]
# #### 2-D Spectral Data

# %%
sample_spectral_filename = 'ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_si.fits'

# %%
hdu_list = fits.open(spectral_path + sample_spectral_filename)
hdu_list.info()
# Out:
# Filename: ./data/PESSTO/Spectral Data/ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_si.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     288   (851, 1011)   float32

# %%
# Display PRIMARY HDU Info
hdu_list[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  851
# NAXIS2  =                 1011
# ORIGIN  = 'ESO     '           / European Southern Observatory
# IRAF-TLM= '2016-07-26T14:27:31' / Time of last modification
# DATE    = '2016-07-26T13:55:24' / UT date when this file was written
# TELESCOP= 'ESO-NTT '           / ESO Telescope Name
# INSTRUME= 'EFOSC   '           / Instrument used.
# OBJECT  = 'ASASSN-14ko'        / Original target.
# RA      =        81.3255416667 / 05:25:18.13 RA (J2000) pointing (deg)
# DEC     =            -46.00565 / -46:00:20.3 DEC (J2000) pointing (deg)
# EQUINOX =                 2000 / Standard FK5 (years)
# RADECSYS= 'FK5     '           / Coordinate reference frame
# EXPTIME =            1500.0148 / Total integration time
# MJD-OBS =        57003.3264101 / MJD start (2014-12-12 07:50:01.832628)
# DATE-OBS= '2014-12-12T07:50:01' / Date of observation
# UTC     =                28194 / 06:42:14.000 UTC at start (sec)
# LST     =            30642.773 / 15:29:43.586 LST at start (sec)
# PI-COI  = 'Smartt  '           / PI-COI name.
# OBSERVER= 'UNKNOWN '           / Name of observer.
# CTYPE1  = 'LINEAR  '           / pixel coordinate system
# CTYPE2  = 'LINEAR  '           / pixel coordinate system
# CRVAL1  =                    1 / RA at ref pixel
# CRVAL2  =                 3347 / DEC at ref pixel
# CRPIX1  =                  1.0 / Ref pixel in X
# CRPIX2  =                  1.0 / Ref pixel in Y
# CDELT1  =                    1 / Binning factor
# CDELT2  =                    4 / Binning factor
# CD1_1   =                  1.0 / Transformation matrix element
# CD2_2   =         4.0775680542 / Transformation matrix element
# HIERARCH ESO ADA ABSROT END = 213.86364 / Abs rot angle at exp end (deg)
# HIERARCH ESO ADA ABSROT START = 214.56656 / Abs rot angle at exp start (deg)
# HIERARCH ESO ADA GUID DEC = -45.87938 / -45:52:45.7 Guide Star DEC J2000
# HIERARCH ESO ADA GUID RA = 81.61060999999999 / 05:26:26.54 Guide Star RA J2000
# HIERARCH ESO ADA GUID STATUS = 'ON      ' / Status of autoguider
# HIERARCH ESO ADA POSANG = 169.554 / Position angle at start
# HIERARCH ESO DET BITS = 16 / Bits per pixel readout
# HIERARCH ESO DET CHIP1 DATE = '2000-08-30' / Date of installation [YYYY-MM-DD]
# HIERARCH ESO DET CHIP1 ID = 'ccd40   ' / Detector chip identification
# HIERARCH ESO DET CHIP1 INDEX = 1 / Chip index
# HIERARCH ESO DET CHIP1 NAME = 'LORAL   ' / Detector chip name
# HIERARCH ESO DET CHIP1 NX = 2048 / # of pixels along X
# HIERARCH ESO DET CHIP1 NY = 2048 / # of pixels along Y
# HIERARCH ESO DET CHIP1 PSZX = 15 / Size of pixel in X
# HIERARCH ESO DET CHIP1 PSZY = 15 / Size of pixel in Y
# HIERARCH ESO DET CHIP1 X = 1 / X location in array
# HIERARCH ESO DET CHIP1 XGAP = 0 / Gap between chips along x
# HIERARCH ESO DET CHIP1 Y = 1 / Y location in array
# HIERARCH ESO DET CHIP1 YGAP = 0 / Gap between chips along y
# HIERARCH ESO DET CHIPS = 1 / # of chips in detector array
# HIERARCH ESO DET DATE = '2000-08-30' / Installation date
# HIERARCH ESO DET DEC = 0 / Apparent 00:00:00.0 DEC at start
# HIERARCH ESO DET DID = 'ESO-VLT-DIC.CCDDCS,ESO-VLT-DIC.FCDDCS' / Diction
# HIERARCH ESO DET EXP NO = 151 / Unique exposure ID number
# HIERARCH ESO DET EXP RDTTIME = 22.39 / image readout time
# HIERARCH ESO DET EXP TYPE = 'Normal  ' / Exposure type
# HIERARCH ESO DET EXP XFERTIM = 22.326 / image transfer time
# HIERARCH ESO DET FRAM ID = 1 / Image sequencial number
# HIERARCH ESO DET FRAM TYPE = 'Normal  ' / Type of frame
# HIERARCH ESO DET ID = 'CCD FIERA - Rev: 3.96' / Detector system Id
# HIERARCH ESO DET NAME = 'efosc - ccdefosc' / Name of detector system
# HIERARCH ESO DET OUT1 CHIP = 1 / Chip to which the output belongs
# HIERARCH ESO DET OUT1 CONAD = 1.1 / Conversion from ADUs to electrons
# HIERARCH ESO DET OUT1 ID = 'L       ' / Output ID as from manufacturer
# HIERARCH ESO DET OUT1 INDEX = 1 / Output index
# HIERARCH ESO DET OUT1 NAME = 'L       ' / Description of output
# HIERARCH ESO DET OUT1 NX = 1024 / valid pixels along X
# HIERARCH ESO DET OUT1 NY = 1024 / valid pixels along Y
# HIERARCH ESO DET OUT1 OVSCX = 0 / Overscan region in X
# HIERARCH ESO DET OUT1 OVSCY = 6 / Overscan region in Y
# HIERARCH ESO DET OUT1 PRSCX = 6 / Prescan region in X
# HIERARCH ESO DET OUT1 PRSCY = 0 / Prescan region in Y
# HIERARCH ESO DET OUT1 X = 2048 / X location of output
# HIERARCH ESO DET OUT1 Y = 1 / Y location of output
# HIERARCH ESO DET OUTPUTS = 1 / # of outputs
# HIERARCH ESO DET OUTREF = 0 / reference output
# HIERARCH ESO DET RA = 0 / Apparent 00:00:00.0 RA at start
# HIERARCH ESO DET READ CLOCK = 'read L port Fast' / Readout clock pattern used
# HIERARCH ESO DET READ MODE = 'normal  ' / Readout method
# HIERARCH ESO DET READ NFRAM = 1 / Number of readouts buffered in sin
# HIERARCH ESO DET READ SPEED = 'fastL   ' / Readout speed
# HIERARCH ESO DET SHUT ID = 'ccd shutter' / Shutter unique identifier
# HIERARCH ESO DET SHUT TMCLOS = 0.079 / Time taken to close shutter
# HIERARCH ESO DET SHUT TMOPEN = 0.05 / Time taken to open shutter
# HIERARCH ESO DET SHUT TYPE = 'Slit    ' / type of shutter
# HIERARCH ESO DET SOFW MODE = 'Normal  ' / CCD sw operational mode
# HIERARCH ESO DET TELE INT = '' / Interval between two successive te
# HIERARCH ESO DET TELE NO = '' / # of sources active
# HIERARCH ESO DET TLM1 END = '' / Telemetry value at read completion
# HIERARCH ESO DET TLM1 ID = '' / ID of telemetry sensor
# HIERARCH ESO DET TLM1 NAME = '' / Description of telemetry param.
# HIERARCH ESO DET TLM1 START = '' / Telemetry value at read start
# HIERARCH ESO DET TLM2 END = '' / Telemetry value at read completion
# HIERARCH ESO DET TLM2 ID = '' / ID of telemetry sensor
# HIERARCH ESO DET TLM2 NAME = '' / Description of telemetry param.
# HIERARCH ESO DET TLM2 START = '' / Telemetry value at read start
# HIERARCH ESO DET TLM3 END = '' / Telemetry value at read completion
# HIERARCH ESO DET TLM3 ID = '' / ID of telemetry sensor
# HIERARCH ESO DET TLM3 NAME = '' / Description of telemetry param.
# HIERARCH ESO DET TLM3 START = '' / Telemetry value at read start
# HIERARCH ESO DET TLM4 END = '' / Telemetry value at read completion
# HIERARCH ESO DET TLM4 ID = '' / ID of telemetry sens
# HIERARCH ESO DET TLM4 NAME = '' / Description of telemetry param.
# HIERARCH ESO DET TLM4 START = '' / Telemetry value at read start
# HIERARCH ESO DET TLM5 END = '' / Telemetry value at read completion
# HIERARCH ESO DET TLM5 ID = '' / ID of telemetry sens
# HIERARCH ESO DET TLM5 NAME = '' / Description of telemetry param.
# HIERARCH ESO DET TLM5 START = '' / Telemetry value at read start
# HIERARCH ESO DET TLM6 END = '' / Telemetry value at read completion
# HIERARCH ESO DET TLM6 ID = '' / ID of telemetry senso
# HIERARCH ESO DET TLM6 NAME = '' / Description of telemetry param.
# HIERARCH ESO DET TLM6 START = '' / Telemetry value at read start
# HIERARCH ESO DET WIN1 BINX = 2 / Binning factor along X
# HIERARCH ESO DET WIN1 BINY = 2 / Binning factor along Y
# HIERARCH ESO DET WIN1 DIT1 = 1500.014763 / actual subintegration time
# HIERARCH ESO DET WIN1 DKTM = 1500.0884 / Dark current time
# HIERARCH ESO DET WIN1 NDIT = 1 / # of subintegrations
# HIERARCH ESO DET WIN1 NX = 1030 / # of pixels along X
# HIERARCH ESO DET WIN1 NY = 1030 / # of pixels along Y
# HIERARCH ESO DET WIN1 ST = T / If T, window enabled
# HIERARCH ESO DET WIN1 STRX = 1 / Lower left pixel in X
# HIERARCH ESO DET WIN1 STRY = 1 / Lower left pixel in Y
# HIERARCH ESO DET WIN1 UIT1 = 1500 / user defined subintegration time
# HIERARCH ESO DET WINDOWS = 1 / # of windows readout
# HIERARCH ESO INS DATE = '2000-06-16' / Instrument release date (yyyy-mm-d
# HIERARCH ESO INS DID = 'ESO-VLT-DIC.EFOSC_ICS-175958' / Data dictionary
# HIERARCH ESO INS DPOR POS = 0.0 / Position move
# HIERARCH ESO INS DPOR ST = F / Instrument depolarizer rotating.
# HIERARCH ESO INS FILT1 ID = 'F1      ' / Filter unique id.
# HIERARCH ESO INS FILT1 NAME = 'Free    ' / Filter name.
# HIERARCH ESO INS FILT1 NO = 1 / Filter wheel position index.
# HIERARCH ESO INS GRIS1 ID = 'F7      ' / OPTIi unique ID.
# HIERARCH ESO INS GRIS1 NAME = 'Gr#11   ' / OPTIi name.
# HIERARCH ESO INS GRIS1 NO = 7 / OPTIi slot number.
# HIERARCH ESO INS GRIS1 TYPE = 'FILTER  ' / OPTIi element.
# HIERARCH ESO INS ID = 'EFOSC/1.57' / Instrument ID.
# HIERARCH ESO INS MODE = 'DEFAULT ' / Instrument mode used.
# HIERARCH ESO INS SLIT1 ENC = 257949 / Slit absolute position [Enc].
# HIERARCH ESO INS SLIT1 LEN = 0.0 / SLIT length [arcsec].
# HIERARCH ESO INS SLIT1 NAME = 'slit#1.0' / Slit common name.
# HIERARCH ESO INS SLIT1 NO = 5 / Slide position.
# HIERARCH ESO INS SLIT1 WID = 0 / SLIT width [arcsec].
# HIERARCH ESO INS SWSIM = 'NORMAL  ' / Software simulation.
# HIERARCH ESO INS WP NAME = 'HALF    ' / WP name, valid values are HALF/QUA
# HIERARCH ESO INS WP ST = 'OUT     ' / WP position.
# HIERARCH ESO OBS DID = 'ESO-VLT-DIC.OBS-1.11' / OBS Dictionary
# HIERARCH ESO OBS EXECTIME = 3614 / Expected execution time
# HIERARCH ESO OBS GRP = 0 / linked blocks
# HIERARCH ESO OBS ID = 100364351 / Observation block ID
# HIERARCH ESO OBS NAME = 'ASASSN-14ko_Spec_V_16_0__17_5_g1' / OB name
# HIERARCH ESO OBS OBSERVER = 'UNKNOWN ' / Observer Name
# HIERARCH ESO OBS PI-COI ID = 2931 / ESO internal PI-COI ID
# HIERARCH ESO OBS PI-COI NAME = 'UNKNOWN ' / PI-COI name
# HIERARCH ESO OBS PROG ID = '191.D-0935(I)' / ESO program identification
# HIERARCH ESO OBS START = '2014-12-12T07:40:55' / OB start time
# HIERARCH ESO OBS TARG NAME = 'ASASSN-14ko' / OB target name
# HIERARCH ESO OBS TPLNO = 2 / Template number within OB
# HIERARCH ESO OCS CON WCSFITS = T / Setup OS to add WCS in fits  .
# HIERARCH ESO OCS DET1 IMGNAME = 'EFOSC_Spectrum' / Data File Name.
# HIERARCH ESO TEL AIRM END = 1.389 / Airmass at end
# HIERARCH ESO TEL AIRM START = 1.296 / Airmass at start
# HIERARCH ESO TEL ALT = 50.436 / Alt angle at start (deg)
# HIERARCH ESO TEL AMBI FWHM END = 0.37 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI FWHM START = 0.41 / Observatory Seeing queried from AS
# HIERARCH ESO TEL AMBI PRES END = 769.6 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI PRES START = 769.6 / Observatory ambient air pressure q
# HIERARCH ESO TEL AMBI RHUM = 29 / Observatory ambient relative humi
# HIERARCH ESO TEL AMBI TEMP = 13.45 / Observatory ambient temperature qu
# HIERARCH ESO TEL AMBI WINDDIR = 28 / Observatory ambient wind directio
# HIERARCH ESO TEL AMBI WINDSP = 2.9 / Observatory ambient wind speed que
# HIERARCH ESO TEL AZ = 51.948 / Az angle at start (deg) S=0,W=90
# HIERARCH ESO TEL CHOP ST = F / True when chopping is active
# HIERARCH ESO TEL DATE = '2009-06-05T01:00:00' / TCS installation date
# HIERARCH ESO TEL DID = 'ESO-VLT-DIC.TCS' / Data dictionary for TEL
# HIERARCH ESO TEL DOME STATUS = 'FULLY-OPEN' / Dome status
# HIERARCH ESO TEL FOCU ID = 'NB      ' / Telescope focus station ID
# HIERARCH ESO TEL FOCU LEN = 38.501 / Focal length (m)
# HIERARCH ESO TEL FOCU SCALE = 5.36 / Focal scale (arcsec/mm)
# HIERARCH ESO TEL FOCU VALUE = -3.32 / M2 setting (mm)
# HIERARCH ESO TEL GEOELEV = 2377 / Elevation above sea level (m)
# HIERARCH ESO TEL GEOLAT = -29.2584 / Tel geo latitute (+=North) (deg)
# HIERARCH ESO TEL GEOLON = -70.7345 / Tel geo longitude (+=East) (deg)
# HIERARCH ESO TEL ID = 'v 254740' / TCS version number
# HIERARCH ESO TEL MOON DEC = 9.613799999999999 / +09:36:49.6 DEC (J2000) (deg)
# HIERARCH ESO TEL MOON RA = 147.450867 / 09:49:48.20 RA (J2000) (deg)
# HIERARCH ESO TEL OPER = 'I. CONDOR' / Telescope Operator
# HIERARCH ESO TEL PARANG END = 86.577 / Parallactic angle at end (deg)
# HIERARCH ESO TEL PARANG START = 81.455 / Parallactic angle at start (deg)
# HIERARCH ESO TEL TARG ALPHA = 52518.13 / Alpha coordinate for the target
# HIERARCH ESO TEL TARG COORDTYPE = 'M       ' / Coordinate type (M=mean A=apparen
# HIERARCH ESO TEL TARG DELTA = -460020.0 / Delta coordinate for the target
# HIERARCH ESO TEL TARG EPOCH = 2000 / Epoch
# HIERARCH ESO TEL TARG EPOCHSYSTEM = 'J       ' / Epoch system (default J=Julian)
# HIERARCH ESO TEL TARG EQUINOX = 2000 / Equinox
# HIERARCH ESO TEL TARG PARALLAX = 0 / Parallax
# HIERARCH ESO TEL TARG PMA = 0.0 / Proper Motion Alpha
# HIERARCH ESO TEL TARG PMD = 0.0 / Proper motion Delta
# HIERARCH ESO TEL TARG RADVEL = 0 / Radial velocity
# HIERARCH ESO TEL TH M1 TEMP = -1 / M1 superficial temperature
# HIERARCH ESO TEL TRAK STATUS = 'NORMAL  ' / Tracking status
# HIERARCH ESO TEL TSS TEMP8 = 11.66 / Temperature Sensing System
# HIERARCH ESO TPL DID = 'ESO-VLT-DIC.TPL-1.9' / Data dictionary for TPL
# HIERARCH ESO TPL EXPNO = 1 / Exposure number within template
# HIERARCH ESO TPL ID = 'EFOSC_spec_obs_Spectrum' / Template signature ID
# HIERARCH ESO TPL NAME = 'Spectroscopy' / Template name
# HIERARCH ESO TPL NEXP = 1 / Number of exposures within templat
# HIERARCH ESO TPL PRESEQ = 'EFOSC_spec_obs_Spectrum.seq' / Sequencer script
# HIERARCH ESO TPL START = '2014-12-12T07:49:36' / TPL start time
# HIERARCH ESO TPL VERSION = '1.0     ' / Version of the template
# ORIGFILE= 'ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1_si.fits' / Original Fi
# ARCFILE = 'ADP.2016-11-17T12:50:58.764.fits' / Archive File Name
# CHECKSUM= 'WejjWchgWchgWchg'   / HDU checksum updated 2016-12-08T14:42:47
# DATASUM = '2797596942'         / data unit checksum updated 2016-08-30T15:50:36
# WCSDIM  =                    2
# LTM1_1  =                    1
# LTM2_2  =                    1
# WAT0_001= 'system=world'
# WAT1_001= 'wtype=linear'
# WAT2_001= 'wtype=linear label=Wavelength units=angstroms'
# TRIM    = 'Jul 26 15:54 Trim data section is [100:950,5:1015]'
# ZEROCOR = 'bias_20141212_Gr11_Free_57595.fits'
# CCDSEC  = '[100:950,5:1015]'
# BIASSEC = '[1:851,1:1011]'
# CCDMEAN =             147.6572
# CCDMEANT=           1154015695
# CCDPROC = 'Jul 26 15:54 CCD processing done'
# FLATCOR = 'nflat_20141211_Gr11_Free_slit1.0_100364358_57595.fits'
# PROV1   = 'EFOSC.2014-12-12T07:50:01.834.fits' / Originating file
# SINGLEXP=                    T / TRUE if resulting from single exposure
# M_EPOCH =                    F / TRUE if resulting from multiple epochs
# FILETYPE=                22209 / pre-reduced image
# NCOMBINE=                    1 / Number of raw science data
# TRACE1  = 'tASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1.fits' / Originating f
# AIRMASS =        1.34110334045 / mean airmass computed with astcalc
# LACOSMIC=                    T / TRUE if Laplacian cosmic ray rejection has been
# FLUXCAL = 'ABSOLUTE'           / Type of flux calibration
# HIERARCH ESO DET OUT1 GAIN = 1.18 / Conversion from electrons to ADU
# HIERARCH ESO DET OUT1 RON = 11.6 / Readout noise per output (e-)
# EFFRON  =        12.9455924405 / Effective readout noise per output (e-)
# PROG_ID = '191.D-0935(I)'      / ESO program identification
# OBSTECH = 'SPECTRUM'           / Observation technique
# REFERENC= 'Smartt et al 2014'  / Bibliographic reference
# PROCSOFT= 'ntt_2.2.8'          / pipeline version
# OBID1   =            100364351 / Observation block ID
# DATAMAX =          896110.0625 / Maximum pixel value
# DATAMIN =        -79626.078125 / Minimal pixel value
# DETRON  =                 11.6 / Readout noise per output (e-)
# GAIN    =                 1.18 / Conversion from electrons to ADU
# PRODCATG= 'ANCILLARY.2DSPECTRUM' / Data product category
# MJD-END =        57003.3437714 / MJD-END = MJD-OBS + JD(exptime)
# QUALITY = 'Final   '           / Final or Fast reduction
# BUNIT   = '10^20 erg/cm2/s/Angstrom' / pixel units
# TEXPTIME=            1500.0148 / Total integ. time of all exposure
# HIERARCH ESO INS MOS1 LEN = 1777 / MOSi slit length [arcsec]
# HIERARCH ESO INS MOS1 POSX = 1002 / MOSi slit position [pix]
# HIERARCH ESO INS MOS1 POSY = 997 / MOSi slit position [pix]
# DCLOG1  = 'Transform'
# DISPAXIS=                    2
# DC-FLAG =                    0
# SPEC_RES=        399.687626026 / Spectral resolving power
# ARC     = 'arc_ASASSN-14ko_20141211_Gr11_Free_slit1.0_57595_1.fits'
# SHIFT   =                 10.2
# WAVELMIN=        334.457229996 / [nm] Minimum wavelength
# VOCLASS = 'SPECTRUM V1.0'      / VO Data Model
# LAMRMS  =                0.013 / residual RMS [nm]
# SPEC_SYE=                  1.0 / systematic error
# SPEC_BW =         412.24213028 / [nm] Bandpass Width Wmax - Wmin
# WAVELMAX=        746.699360275 / [nm] Maximum wavelength
# SPEC_ERR=     0.00459619407771 / statistical uncertainty
# LAMNLIN =                    8 / Nb of arc lines used in the fit of the wavel. s
# VOPUB   = 'ESO/SAF '           / VO Publishing Authority
# APERTURE=            0.0002778 / [deg] Aperture diameter
# SPEC_VAL=        540.578295135 / [nm] Mean Wavelength
# SPEC_BIN=               0.4082 / average spectral coordinate bin size [nm/pix]
# FLUXERR =                 15.2 / Fractional uncertainty of the flux [%]
# EXT_OBJ =                    F / TRUE if extened
# DISPELEM= 'Gr#11   '           / Dispersive element name
# TELAPSE =            1500.0148 / Total elapsed time [s]
# SPECSYS = 'TOPOCENT'           / Observed frame
# TITLE   = 'ASASSN-14ko'        / Dataset title
# TMID    =        57003.3350908 /  [d] MJD mid exposure
# CONTNORM=                    F / TRUE if normalised to the continuum
# TOT_FLUX=                    F / TRUE if phot. cond. and all src flux is capture
# SENSFUN = 'sens_20141211_Gr11_Free_gd71_57595_1.fits'
# DATA_REL= 'SSDR3   '           / Data Release Version
# P3ORIG  = 'EDP     '           / ESO external data product

# %% [markdown]
# Likewise, this catalog contains two headers where the first is the file metadata, and the second is a binary table with the contents of the catalogue.

# %%
spectral_data = hdu_list[0].data

# %%
# Close HDU file
hdu_list.close()

# %%
plt.figure(figsize=(5,5))
plt.imshow(spectral_data)
plt.colorbar()

# %% [markdown]
# #### Sample Catalogue row

# %%
#image_data /= 255.0
minpx = np.mean(spectral_data)-2.5*np.std(spectral_data) 
maxpx = np.mean(spectral_data)+2.5*np.std(spectral_data)

plt.figure(figsize=(7,7))
plt.imshow(spectral_data, origin='lower', cmap='gray', vmin=minpx, vmax=maxpx)
plt.plot([ X ],[Y], 'r+')

# %% [markdown]
# #### Count number of NaNs per column

# %%
# Proportion of null values per column
total = spectral_.isnull().sum()
proportion = spectral_df.isnull().sum() / len(spectral_df)*100
pd.concat([total, proportion], axis=1, keys= ['Total', 'Percentage'])
