# %%
import tools, timeit, os
import pandas as pd
from astropy.io import fits
from astropy.utils.data import download_file
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
# %config InlineBackend.rc = {}
# %matplotlib inline

# %%
data_path = './data/PTF'
metadata_path = data_path + '/metadata'
tbl_filename = 'ptf_photcalcat_v1.tbl'
metadata_page = 'http://irsa.ipac.caltech.edu/ibe/search/ptf/images/level1?POS={},{}'
images_page = 'http://irsa.ipac.caltech.edu/ibe/data/ptf/images/level1'

# %% [markdown]
# ## Data information

# %% [markdown]
# The PTF's .tbl (IPAC) file size is too big to be opened with other libraries. So first it will be converted to a dataframe, and then stored as a CSV. Storing it as a .pickle file would crash the Python process after a while.

# %%
tbl_path = data_path + '/' + tbl_filename
df = tools.table_to_dataframe(tbl_path)
# Out:
# 21167682
# ---------------------------------------------------
# KeyboardInterrupt Traceback (most recent call last)
# <ipython-input-8-17c34530745d> in <module>()
#       1 tbl_path = data_path + '/' + tbl_filename
# ----> 2 df = tools.table_to_dataframe(tbl_path)
#
# ~/Desktop/astro/tools.py in table_to_dataframe(path)
#      40             col_name = col_names[j]
#      41             data[col_name].append(value)
# ---> 42             j += 1
#      43         index += 1
#      44
#
# KeyboardInterrupt:

# %% [markdown]
# #### Persist as .csv

# %%
# We'll count how long this takes
start_time = timeit.default_timer()
df.to_csv(data_path + '/ptf.csv')
end_time = timeit.default_timer()
print('TIME ELAPSED', end_time-start_time)

# %% [markdown]
# ### Load from file

# %% [markdown]
# Next time, the dataframe may be loaded into memory by running:

# %%
# We'll count too how long this takes
start = timeit.default_timer();
df = pd.DataFrame.from_csv(data_path + '/ptf.csv');
end = timeit.default_timer();
print(end-start)
# Out:
# 90.68730476900237

# %% [markdown]
# #### Table Description

# %%
df.head()
# Out:
#    ErrMu  MuType  PTFFIELD   Rerr  Rmerr  Rperr    Rptf  bstRMS  cI  \
# 0  0.095   0.058    100111  0.021  0.017  0.026  16.152   0.022   9
# 1  0.060   0.058    100111  0.030  0.022  0.037  17.172   0.022   9
# 2  0.106   0.106    100111  0.063  0.055  0.071  18.507   0.022   9
# 3  0.072   0.046    100111  0.015  0.017  0.014  14.225   0.022   9
# 4  0.063   0.003    100111  0.025  0.029  0.022  15.286   0.022   9
#
#          dec  flag  nP  nT         ra
# 0 -31.087161     1  23  12  42.532500
# 1 -31.086008     1  21  12  42.786188
# 2 -31.085419     1  22  12  42.593730
# 3 -31.081556     1  23  12  42.525416
# 4 -31.080395     1  23  12  42.953363

# %% [markdown]
# #### Sample

# %%
df.iloc[0]
# Out:
# ErrMu            0.095000
# MuType           0.058000
# PTFFIELD    100111.000000
# Rerr             0.021000
# Rmerr            0.017000
# Rperr            0.026000
# Rptf            16.152000
# bstRMS           0.022000
# cI               9.000000
# dec            -31.087161
# flag             1.000000
# nP              23.000000
# nT              12.000000
# ra              42.532500
# Name: 0, dtype: float64

# %%
df.loc[df['flag'] == 0]
# Out:
# Empty DataFrame
# Columns: [ErrMu, MuType, PTFFIELD, Rerr, Rmerr, Rperr, Rptf, bstRMS, cI, dec, flag, nP, nT, ra]
# Index: []

# %% [markdown]
# #### Get RaDec coordinates for a given row

# %%
row_number = 0
row = df.iloc[row_number]
row[['ra', 'dec']]
# Out:
# ra     42.532500
# dec   -31.087161
# Name: 0, dtype: float64

# %% [markdown]
# #### And metadata url for given pos

# %% [markdown]
# ### Download metadata for given position

# %% [markdown]
# #### Create URL

# %%
pos_metadata_url = metadata_page.format(row['ra'], row['dec'])
print(pos_metadata_url)
# Out:
# http://irsa.ipac.caltech.edu/ibe/search/ptf/images/level1?POS=42.5325,-31.087161

# %% [markdown]
# ### Retrieve metadata

# %% [markdown]
# #### Create metadata directory if not exists

# %%
if not os.path.exists(metadata_path):
    os.makedirs(metadata_path)

# %% [markdown]
# #### Download

# %%
from urllib.request import urlretrieve
destination_path = metadata_path + '/{}_{}.tbl'.format(row['ra'], row['dec'])
urlretrieve(pos_metadata_url, destination_path)
# Out:
# ('./data/PTF/metadata/42.5325_-31.087161.tbl',
#  <http.client.HTTPMessage at 0x17aded2e8>)

# %% [markdown]
# #### Load metadata

# %%
from astropy.table import Table
t = Table.read(destination_path, format='ipac')

# %%
metadf = t.to_pandas()
metadf.head()
# Out:
#    in_row_id    in_ra     in_dec     expid                     obsdate  \
# 0        1.0  42.5325 -31.087161   40952.0  2009-09-21 09:59:23.116000
# 1        1.0  42.5325 -31.087161   51958.0  2010-01-01 02:36:13.958000
# 2        1.0  42.5325 -31.087161  186371.0  2011-08-21 11:17:49.311000
# 3        1.0  42.5325 -31.087161   44264.0  2009-11-02 08:20:40.913000
# 4        1.0  42.5325 -31.087161   55916.0  2010-01-12 03:35:40.105000
#
#       crval1     crval2 filter  ccdid  ptffield         ...           \
# 0  42.916240 -31.067953      R    9.0  100111.0         ...
# 1  42.942199 -30.987374      R    9.0  100111.0         ...
# 2  42.942311 -30.987065      R    9.0  100111.0         ...
# 3  42.942305 -30.987058      R    9.0  100111.0         ...
# 4  42.942278 -30.987003      R    9.0  100111.0         ...
#
#         dec2        ra3       dec3        ra4       dec4  gain  readnoi  \
# 0 -29.993927  43.187355 -31.146457  42.514795 -31.148766   1.5      3.9
# 1 -29.942166  43.177478 -31.095500  42.505185 -31.097745   1.5      3.9
# 2 -29.959757  43.172462 -31.112563  42.499730 -31.115045   1.5      3.9
# 3 -29.945939  43.177962 -31.098515  42.505527 -31.101076   1.5      3.9
# 4 -29.941795  43.183548 -31.094279  42.511169 -31.097123   1.5      3.9
#
#    darkcur ipac_gid        ipac_pub_date
# 0      0.1    100.0  2015-08-07 00:00:00
# 1      0.1    100.0  2015-08-07 00:00:00
# 2      0.1    100.0  2015-08-07 00:00:00
# 3      0.1    100.0  2015-08-07 00:00:00
# 4      0.1    100.0  2015-08-07 00:00:00
#
# [5 rows x 45 columns]

# %%
metadf.columns.values
# Out:
# array(['in_row_id', 'in_ra', 'in_dec', 'expid', 'obsdate', 'crval1',
#        'crval2', 'filter', 'ccdid', 'ptffield', 'seeing', 'airmass',
#        'moonillf', 'moonesb', 'photcalflag', 'infobits', 'nid', 'fieldid',
#        'ptfpid', 'pfilename', 'afilename1', 'afilename2', 'afilename3',
#        'afilename4', 'rfilename', 'obsmjd', 'ptfprpi', 'filtersl',
#        'moonra', 'moondec', 'moonphas', 'moonalt', 'ra1', 'dec1', 'ra2',
#        'dec2', 'ra3', 'dec3', 'ra4', 'dec4', 'gain', 'readnoi', 'darkcur',
#        'ipac_gid', 'ipac_pub_date'], dtype=object)

# %%
metadf.describe()
# Out:
#        in_row_id         in_ra        in_dec          expid      crval1  \
# count      106.0  1.060000e+02  1.060000e+02     106.000000  106.000000
# mean         1.0  4.253250e+01 -3.108716e+01  164842.009434   42.979511
# std          0.0  1.427837e-14  7.139183e-15   58657.550060    0.030457
# min          1.0  4.253250e+01 -3.108716e+01   40952.000000   42.802978
# 25%          1.0  4.253250e+01 -3.108716e+01  185301.000000   42.977097
# 50%          1.0  4.253250e+01 -3.108716e+01  192829.000000   42.977219
# 75%          1.0  4.253250e+01 -3.108716e+01  199422.500000   42.977432
# max          1.0  4.253250e+01 -3.108716e+01  206614.000000   43.025978
#
#            crval2  ccdid  ptffield      seeing     airmass    ...     \
# count  106.000000  106.0     106.0  104.000000  106.000000    ...
# mean   -30.487128    9.0  100111.0    2.844904    2.307264    ...
# std      0.207718    0.0       0.0    0.637906    0.091896    ...
# min    -31.067953    9.0  100111.0    1.920000    2.220000    ...
# 25%    -30.415376    9.0  100111.0    2.407500    2.240000    ...
# 50%    -30.415162    9.0  100111.0    2.715000    2.260000    ...
# 75%    -30.414904    9.0  100111.0    3.070000    2.370000    ...
# max    -30.357943    9.0  100111.0    5.050000    2.490000    ...
#
#               ra2        dec2         ra3        dec3         ra4        dec4  \
# count  106.000000  106.000000  106.000000  106.000000  106.000000  106.000000
# mean    43.165840  -29.957924   43.175094  -31.110218   42.502245  -31.112846
# std      0.004191    0.009655    0.004067    0.009590    0.004261    0.009629
# min     43.158394  -29.994315   43.167640  -31.146734   42.494912  -31.149254
# 25%     43.163036  -29.961495   43.172643  -31.113735   42.499370  -31.116301
# 50%     43.165251  -29.959890   43.174351  -31.112159   42.501494  -31.114840
# 75%     43.168184  -29.956687   43.177468  -31.108466   42.504832  -31.111181
# max     43.182686  -29.940586   43.191147  -31.093128   42.518626  -31.095414
#
#         gain       readnoi       darkcur  ipac_gid
# count  106.0  1.060000e+02  1.060000e+02     106.0
# mean     1.5  3.900000e+00  1.000000e-01     100.0
# std      0.0  1.338597e-15  1.394372e-17       0.0
# min      1.5  3.900000e+00  1.000000e-01     100.0
# 25%      1.5  3.900000e+00  1.000000e-01     100.0
# 50%      1.5  3.900000e+00  1.000000e-01     100.0
# 75%      1.5  3.900000e+00  1.000000e-01     100.0
# max      1.5  3.900000e+00  1.000000e-01     100.0
#
# [8 rows x 34 columns]

# %% [markdown]
# ### Sample data

# %%
meta_row_number = 0
meta_row = metadf.iloc[meta_row_number]
meta_row
# Out:
# in_row_id                                                        1
# in_ra                                                      42.5325
# in_dec                                                    -31.0872
# expid                                                        40952
# obsdate                                 2009-09-21 09:59:23.116000
# crval1                                                     42.9162
# crval2                                                     -31.068
# filter                                                           R
# ccdid                                                            9
# ptffield                                                    100111
# seeing                                                        2.33
# airmass                                                       2.26
# moonillf                                                      0.09
# moonesb                                                          0
# photcalflag                                                      0
# infobits                                                         0
# nid                                                            207
# fieldid                                                      40952
# ptfpid                                                       10010
# pfilename        proc/2009/09/21/f2/c9/p5/v2/PTF_200909214162_i...
# afilename1       proc/2009/09/21/f2/c9/p5/v2/PTF_200909214162_i...
# afilename2       proc/2009/09/21/f2/c9/p5/v2/PTF_200909214162_i...
# afilename3       proc/2009/09/21/f2/c9/p5/v2/PTF_200909214162_c...
# afilename4                                                     NaN
# rfilename        raw/2009/09/21/f02/multiExt/PTF200909214162_2_...
# obsmjd                                                     55095.4
# ptfprpi                                                   Kulkarni
# filtersl                                                         2
# moonra                                                     208.959
# moondec                                                    -17.494
# moonphas                                                    145.64
# moonalt                                                     -73.64
# ra1                                                        42.5135
# dec1                                                       -29.996
# ra2                                                        43.1785
# dec2                                                      -29.9939
# ra3                                                        43.1874
# dec3                                                      -31.1465
# ra4                                                        42.5148
# dec4                                                      -31.1488
# gain                                                           1.5
# readnoi                                                        3.9
# darkcur                                                        0.1
# ipac_gid                                                       100
# ipac_pub_date                                  2015-08-07 00:00:00
# Name: 0, dtype: object

# %%
meta_pfilename = meta_row['pfilename']
meta_pfilename
# Out:
# 'proc/2009/09/21/f2/c9/p5/v2/PTF_200909214162_i_p_scie_t095923_u011929627_f02_p100111_c09.fits'

# %% [markdown]
# ## Viewing & manipulating image

# %%
image_url = images_page + '/' + meta_pfilename
image_file = download_file(image_url)
# Out:
# Downloading http://irsa.ipac.caltech.edu/ibe/data/ptf/images/level1/proc/2009/09/21/f2/c9/p5/v2/PTF_200909214162_i_p_scie_t095923_u011929627_f02_p100111_c09.fits [Done]

# %%
hdu_list = fits.open(image_file)

# %%
hdu_header = hdu_list[0].header
hdu_header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / FOUR-BYTE SINGLE PRECISION FLOATING POINT
# NAXIS   =                    2 / STANDARD FITS FORMAT
# NAXIS1  =                 2048 / STANDARD FITS FORMAT
# NAXIS2  =                 4096 / STANDARD FITS FORMAT
# ORIGIN  = 'Palomar Transient Factory' / Origin of these image data
# CREATOR = 'Infrared Processing and Analysis Center' / Creator of this FITS file
# TELESCOP= 'P48     '           / Name of telescope
# INSTRUME= 'PTF/MOSAIC'         / Instrument name
# OBSERVER= 'KulkarniPTF'        / Observer name and project
# CCDID   = '9       '           / CCD number (0..11)
# DATE-OBS= '2009-09-21T09:59:23.116' / UTC shutter time YYYY-MM-DDTHH:MM:SS.SSS
# DATE    = '2012-02-14T15:25:37' / File creation date (YYYY-MM-DDThh:mm:ss UT)
# REFERENC= 'http://www.astro.caltech.edu/ptf' / URL of PTF website
#
#           / PROPOSAL INFORMATION
#
# PTFPRPI = 'Kulkarni'           / PTF Project PI
# PTFPID  = '10010   '           / Project type: 00000-49999
# OBJECT  = 'PTF_survey'         / Fields object
# PTFFIELD= '100111  '           / PTF unique field ID
# PTFFLAG = '1       '           / 1 = PTF; 0 = non-PTF category
#
#           / TIME AND EXPOSURE INFORMATION
#
# FILTER  = 'R       '           / Filter name
# FILTERID= '2       '           / Filter ID
# FILTERSL= '2       '           / Filter changer slot position
# EXPTIME =                  60. / [s] Requested exposure time
# AEXPTIME=                  60. / actual exposure time (sec)
# UTC-OBS = '2009-09-21T09:59:23.116' / UTC time shutter open YYYY-MM-DDTHH:MM:SS.
# OBSJD   =        2455095.91624 / [day] Julian day corresponds to UTC-OBS
# OBSMJD  =          55095.41624 / MJD corresponds to UTC-OBS (day)
# OBSLST  = '2:13:36.38'         / Mean LST corresponds to UTC-OBS 'HH:MM:SS.S'
# HOURANG = '-0:36:48.01'        / Mean HA (sHH:MM:SS.S) based on LMST at UTC-OBS
# HJD     =        2455095.91987 / [day] Heliocentric Julian Day
# OBSTYPE = 'object  '           / Image type (dark,science,bias,focus)
# IMGTYP  = 'object  '           / Image type (dark,science,bias,focus)
#
#           / MOON AND SUN
#
# MOONRA  =           208.958921 / [deg] Moon J2000.0 R.A.
# MOONDEC =           -17.494023 / [deg] Moon J2000.0 Dec.
# MOONILLF=             0.087258 / [frac] Moon illuminated fraction
# MOONPHAS=             145.6375 / [deg] Moon phase angle
# MOONESB =                  -0. / Moon excess in sky brightness V-band
# MOONALT =            -73.64317 / [deg] Moon altitude
# SUNAZ   =             51.06184 / [deg] Sun azimuth
# SUNALT  =             -42.9129 / [deg] Sun altitude
#
#           / PHOTOMETRY
#
# BUNIT   = 'DN      '           / Data number (analog-to-digital units or ADU)
# PHTCALEX=                    1 / Was phot.-cal. module executed?
# PHTCALFL=                    0 / Flag for image is photometric (0=N, 1=Y)
# PCALRMSE=             0.017829 / RMSE from (zeropoint, extinction) data fit
# IMAGEZPT=             22.93225 / Image magnitude zeropoint
# IZPORIG = 'CALTRANS'           / Photometric-calibration origin
# ZPRULE  = 'COMPUTE '           / Photometric-calibration method
# MAGZPT  =             23.15677 / Magnitude zeropoint at airmass=1
# EXTINCT =             0.097087 / Extinction
# APSFILT = 'r       '           / SDSS filter used in abs phot cal
# APSCOL  = 'r-i     '           / SDSS color used in abs phot cal
# APRMS   =           0.03372327 / RMS in mag of final abs phot cal
# APBSRMS =           0.02081749 / RMS in mag of final abs phot cal for bright sta
# APNSTDI1=                37802 / Number of standard stars in first iteration
# APNSTDIF=                35265 / Number of standard stars in final iteration
# APCHI2  =       55776.52892715 / Chi2 of final abs phot cal
# APDOF   =               35254. / Dof of chi2 of final abs phot cal
# APMEDJD =     2455095.85049722 / Median JD used in abs phot cal
# APPN01  = 'ZeroPoint'          / Name of parameter abs phot cal 01
# APPAR01 =          23.28566063 / Value of parameter abs phot cal 01
# APPARE01=           0.00146843 / Error of parameter abs phot cal 01
# APPN02  = 'ColorTerm'          / Name of parameter abs phot cal 02
# APPAR02 =           0.20057296 / Value of parameter abs phot cal 02
# APPARE02=           0.00201675 / Error of parameter abs phot cal 02
# APPN03  = 'AirMassTerm'        / Name of parameter abs phot cal 03
# APPAR03 =          -0.10959685 / Value of parameter abs phot cal 03
# APPARE03=           0.00088364 / Error of parameter abs phot cal 03
# APPN04  = 'AirMassColorTerm'   / Name of parameter abs phot cal 04
# APPAR04 =           0.00571876 / Value of parameter abs phot cal 04
# APPARE04=           0.00122926 / Error of parameter abs phot cal 04
# APPN05  = 'TimeTerm'           / Name of parameter abs phot cal 05
# APPAR05 =          -0.05821963 / Value of parameter abs phot cal 05
# APPARE05=           0.00820686 / Error of parameter abs phot cal 05
# APPN06  = 'Time2Term'          / Name of parameter abs phot cal 06
# APPAR06 =          -0.13964736 / Value of parameter abs phot cal 06
# APPARE06=           0.06550368 / Error of parameter abs phot cal 06
# APPN07  = 'XTerm   '           / Name of parameter abs phot cal 07
# APPAR07 =           0.01447985 / Value of parameter abs phot cal 07
# APPARE07=           0.00071701 / Error of parameter abs phot cal 07
# APPN08  = 'YTerm   '           / Name of parameter abs phot cal 08
# APPAR08 =           0.03010033 / Value of parameter abs phot cal 08
# APPARE08=           0.00181278 / Error of parameter abs phot cal 08
# APPN09  = 'Y2Term  '           / Name of parameter abs phot cal 09
# APPAR09 =           0.00996656 / Value of parameter abs phot cal 09
# APPARE09=           0.00313049 / Error of parameter abs phot cal 09
# APPN10  = 'Y3Term  '           / Name of parameter abs phot cal 10
# APPAR10 =          -0.03870108 / Value of parameter abs phot cal 10
# APPARE10=           0.01221561 / Error of parameter abs phot cal 10
# APPN11  = 'XYTerm  '           / Name of parameter abs phot cal 11
# APPAR11 =          -0.02303354 / Value of parameter abs phot cal 11
# APPARE11=           0.00255773 / Error of parameter abs phot cal 11
#
#           / ASTROMETRY
#
# CRVAL1  =     42.9162398768311 / [deg] RA of reference point
# CRVAL2  =    -31.0679528687605 / [deg] DEC of reference point
# CRPIX1  =             1224.424 / [pix] Image reference point
# CRPIX2  =             3812.211 / [pix] Image reference point
# CTYPE1  = 'RA---TAN-SIP'       / TAN (gnomic) projection + SIP distortions
# CTYPE2  = 'DEC--TAN-SIP'       / TAN (gnomic) projection + SIP distortions
# CUNIT1  = 'deg     '           / Image axis-1 celestial-coordinate units
# CUNIT2  = 'deg     '           / Image axis-2 celestial-coordinate units
# CRTYPE1 = 'deg     '           / Data units of CRVAL1
# CRTYPE2 = 'deg     '           / Data units of CRVAL2
# CD1_1   = 0.000281166813862577 / Transformation matrix
# CD1_2   = 1.14785761050997E-06
# CD2_1   = 1.25119381113606E-06
# CD2_2   = -0.000281035163583045
# OBJRA   = '02:50:00.504'       / Requested field J2000.0 Ra.
# OBJDEC  = '-29:55:12.72'       / Requested field J2000.0 Dec.
# OBJRAD  =            42.502102 / [deg] Requested field RA (J2000.0)
# OBJDECD =             -29.9202 / [deg] Requested field Dec (J2000.0)
# PIXSCALE=                 1.01 / [arcsec/pix] Pixel scale
# WCSAXES =                    2
# EQUINOX =                2000. / [yr] Equatorial coordinates definition
# LONPOLE =                 180.
# LATPOLE =                   0.
#
#           / IMAGE QUALITY
#
# SEEING  =                 2.33 / [pix] Seeing FWHM
# PEAKDIST=     0.40315024670668 / [pix] Mean dist brightest pixel-centroid pixel
# ELLIP   =               0.0735 / Mean image ellipticity A/B
# ELLIPPA =                38.47 / [deg] Mean image ellipticity PA
# FBIAS   =             1003.862 / [DN] Floating bias of the image
# SATURVAL=               19000. / [DN] Saturation value of the CCD array
# FWHMSEX =                 2.25 / [arcsec] SExtractor SEEING estimate
# MDSKYMAG=             20.30328 / [mag/s-arcsec^2] Median sky obsolete
# MSMAPCZP=             20.39882 / [mag/s-arcsec^2] Median sky abs. phot. cal.
# LIMITMAG=             21.08561 / [mag/s-arcsec^2] Limiting magnitude obsolete
# LMGAPCZP=             21.18115 / [mag/s-arcsec^2] Limiting mag. abs. phot. cal.
# MEDFWHM =             3.260936 / [arcsecond] Median FWHM
# MEDELONG=             1.198189 / [dimensionless] Median elongation
# STDELONG=             2.296717 / [dimensionless] Std. dev. of elongation
# MEDTHETA=            -37.57536 / [deg] Atan(median sin(theta)/median cos(theta))
# STDTHETA=             66.68537 / [deg] Atan(stddev sin(theta)/stddev cos(theta))
# MEDDLMAG=             29.60057 / [mag/s-arcsec^2] Median (MU_MAX-MAG_AUTO)
# STDDLMAG=             2.801844 / [mag/s-arcsec^2] Stddev of (MU_MAX-MAG_AUTO)
#
#           / OBSERVATORY AND TCS
#
# OCS_TIME= '2009-09-21T09:59:23.065' / UTC Date for OCS calc time-dep params
# OPERMODE= 'OCS     '           / Mode of operation: OCS | Manual | N/A
# SOFTVER = '1.1.1.1 '           / Softwere version (TCS.Camera.OCS.Sched)
# OCS_VER = '1       '           / OCS software version and date
# TCS_VER = '1       '           / TCS software version and date
# SCH_VER = '1       '           / OCS-Scheduler software version and date
# MAT_VER = '7.7.0.471'          / Matlab version
# HDR_VER = '1       '           / Header version
# TRIGGER = 'N/A     '           / trigger ID for TOO, e.g. VOEVENT-Nr
# TCSMODE = 'Star    '           / TCS fundamental mode
# TCSSMODE= 'Active  '           / TCS fundamental submode
# TCSFMODE= 'Pos     '           / TCS focus mode
# TCSFSMOD= 'On-Target'          / TCS focus submode
# TCSDMODE= 'Stop    '           / TCS dome mode
# TCSDSMOD= 'N/A     '           / TCS dome submode
# TCSWMODE= 'Slave   '           / TCS windscreen mode
# TCSWSMOD= 'N/A     '           / TCS windscreen submode
# OBSLAT  =              33.3574 / [deg] Telescope geodetic latitude in WGS84
# OBSLON  =             116.8599 / [deg] Telescope geodetic longitude in WGS84
# OBSALT  =               1703.2 / [m] Telescope geodetic altitude in WGS84
# DEFOCUS =                   0. / [mm] Focus position - nominal focus
# FOCUSPOS=               1.3622 / [mm] Exposures focusPos
# DOMESTAT= 'open    '           / Dome status at begining of exposure
# TRACKRA =                 23.4 / [arcsec/hr] Track speed RA rel to sidereal
# TRACKDEC=                 -4.5 / [arcsec/hr] Track speed Dec rel to sidereal
# AZIMUTH =              171.213 / [deg] Telescope Azimuth
# ALTITUDE=             26.13889 / [deg] Telescope altitude
# AIRMASS =             2.261299 / Telescope airmass
# TELRA   =             42.60164 / [deg] Telescope ap equinox of date RA
# TELDEC  =             -29.8804 / [deg] Telescope ap equinox of date Dec
# TELHA   =             350.7964 / [deg] Telescope ap equinox of date HA
# DOMEAZ  =             170.8485 / [deg] Dome azimuth
# WINDSCAL=               11.246 / [deg] Wind screen altitude
# WINDDIR =                   2. / [deg] Azimuth of wind direction
# WINDSPED=              12.3816 / Wind speed (km/hour)
# OUTTEMP =             17.88889 / [C] Outside temperature
# OUTRELHU=                0.413 / [frac] Outside relative humidity
# OUTDEWPT=             4.555556 / [C] Outside dew point
#
#           / INSTRUMENT TELEMETRY
#
# PANID   = '_p48s   '           / PAN identification
# DHSID   = '_p48s   '           / DHS identification
# ROISTATE= 'ROI     '           / ROI State (FULL | ROI)
# CCDSEC  = '[1:2048,1:4096]'    / CCD section
# CCDSIZE = '[1:2048,1:4096]'    / CCD size
# DATASEC = '[1:2048,1:4096]'    / Data section
# DETSEC  = '[1:2048,1:4096]'    / Detector section
# ROISEC  = '[1:2048,1:4096]'    / ROI section
# FPA     = 'P48MOSAIC'          / Focal plan array
# CCDNAME = '8-11-2  '           / Detector mfg serial number
# CHECKSUM= 'JifALgf3Jgf9Jgf9'   / HDU checksum updated 2010-03-15T13:06:37
# DATASUM = '1012798873'         / Data unit checksum updated 2010-03-15T13:06:37
# DHEINF  = 'SDSU, Gen-III'      / Controller info
# DHEFIRM = '/usr/src/dsp/tim_m.lod.1x' / DSP software
# CAM_VER = '20090615.1.3.100000' / Camera server date.rev.cfitsio
# LV_VER  = '8.5     '           / LabVIEW software version
# PCI_VER = '2.0c    '           / Astropci software version
# DETID   = 'PTF/MOSAIC'         / Detector ID
# AUTHOR  = 'PTF/OCS/TCS/Camera' / Source for header information
# DATAMIN =                   0. / Minimum value for array
# ROISTATE= 'ROI     '           / ROI State (FULL | ROI)
# LEDBLUE = 'OFF     '           / 470nm LED state (ON | OFF)
# LEDRED  = 'OFF     '           / 660nm LED state (ON | OFF)
# LEDNIR  = 'OFF     '           / 880nm LED state (ON | OFF)
# CCD9TEMP=              175.003 / [K] 0x0 servo temp sensor on CCD09
# HSTEMP  =              147.664 / [K] 0x1 heat spreader temp
# DHE0TEMP=              294.294 / [K] 0x2 detector head electronics temp, master
# DHE1TEMP=              296.648 / [K] 0x3 detector head electronics temp, slave
# DEWWTEMP=              286.711 / [K] 0x4 dewar wall temp
# HEADTEMP=              138.047 / [K] 0x5 cryo cooler cold head temp
# CCD5TEMP=              175.104 / [K] 0x6 temp sensor on CCD05
# CCD11TEM=              176.041 / [K] 0x7 temp sensor on CCD11
# CCD0TEMP=              169.203 / [K] 0x8 temp sensor on CCD00
# RSTEMP  =              233.249 / [K] 0x9 temp sensor on radiation shield
# DEWPRESS=                 0.52 / [milli-torr] Dewar pressure
# DETHEAT =                 38.8 / [%] Detector focal plane heater power
# NAMPSXY = '6 2     '           / Number of amplifiers in x y
# CCDSUM  = '1 1     '           / [pix] Binning in x and y
# MODELFOC= 'N/A     '           / MODELFOC
# CHECKSUM= 'JVJHJVIEJVIEJVIE'   / HDU checksum updated 2010-03-15T13:06:37
# DATASUM = '         0'         / Data unit checksum (2010-03-15T13:06:37)
# GAIN    =                  1.5 / [e-/D.N.] Gain of detector.
# READNOI =                  3.9 / [e-] Read noise of detector.
# DARKCUR =                  0.1 / [e-/s] Dark current of detector
#
#           / SCAMP DISTORTION KEYWORDS
#
# RADECSYS= 'ICRS    '           / Astrometric system
# PV1_0   =                   0. / Projection distortion parameter
# PV1_1   =                   1. / Projection distortion parameter
# PV1_2   =                   0. / Projection distortion parameter
# PV1_4   = -0.000209578174040344 / Projection distortion parameter
# PV1_5   = -0.000387526224481786 / Projection distortion parameter
# PV1_6   = 0.000114976598933686 / Projection distortion parameter
# PV1_7   = -0.00261867247630265 / Projection distortion parameter
# PV1_8   = -0.00552767299499143 / Projection distortion parameter
# PV1_9   =  0.00173070467687927 / Projection distortion parameter
# PV1_10  =  -0.0011289769141386 / Projection distortion parameter
# PV1_12  =  0.00620012349308177 / Projection distortion parameter
# PV1_13  =  0.00496169358251172 / Projection distortion parameter
# PV1_14  =  0.00615522027334153 / Projection distortion parameter
# PV1_15  = -0.000917589078831827 / Projection distortion parameter
# PV1_16  = 0.000710915523258548 / Projection distortion parameter
# PV2_0   =                   0. / Projection distortion parameter
# PV2_1   =                   1. / Projection distortion parameter
# PV2_2   =                   0. / Projection distortion parameter
# PV2_4   =  0.00321996080772265 / Projection distortion parameter
# PV2_5   = -0.000232749229214685 / Projection distortion parameter
# PV2_6   = -4.16944181102081E-05 / Projection distortion parameter
# PV2_7   = -0.00301629615299176 / Projection distortion parameter
# PV2_8   = 0.000209689020600846 / Projection distortion parameter
# PV2_9   = -0.00125349642021371 / Projection distortion parameter
# PV2_10  =  0.00228669358644741 / Projection distortion parameter
# PV2_12  =   0.0012621055622757 / Projection distortion parameter
# PV2_13  = -6.25851520940944E-05 / Projection distortion parameter
# PV2_14  =  0.00128741448769529 / Projection distortion parameter
# PV2_15  = -0.00332776602872163 / Projection distortion parameter
# PV2_16  =  0.00504379676162703 / Projection distortion parameter
# FGROUPNO=                    1 / SCAMP field group label
# ASTIRMS1=                   0. / Astrom. dispersion RMS (intern., high S/N)
# ASTIRMS2=                   0. / Astrom. dispersion RMS (intern., high S/N)
# ASTRRMS1=         4.532105E-05 / Astrom. dispersion RMS (ref., high S/N)
# ASTRRMS2=         2.921083E-05 / Astrom. dispersion RMS (ref., high S/N)
# ASTINST =                    1 / SCAMP astrometric instrument label
# FLXSCALE=                   0. / SCAMP relative flux scale
# MAGZEROP=                   0. / SCAMP zero-point
# PHOTIRMS=                   0. / mag dispersion RMS (internal, high S/N)
# RA_RMS  =            0.2783833 / [arcsec] RMS of SCAMP fit from 2MASS matching
# DEC_RMS =            0.2637296 / [arcsec] RMS of SCAMP fit from 2MASS matching
# ASTROMN =                   82 / Number of stars in SCAMP astrometric solution
# SCAMPPTH= '/ptf/pos/archive/fallbackcal/scamp/9/' / SCAMP catalog path
# SCAMPFIL= 'PTF_201011182981_c_e_uca3_t070920_u002761444_f02_p100111_c09.fits'
#
#           / SIP DISTORTION KEYWORDS
#
# A_ORDER =                    4 / Distortion order for A
# A_0_2   = 3.64357257862639E-08 / Projection distortion parameter
# A_0_3   = 9.06622184543192E-11 / Projection distortion parameter
# A_0_4   = 1.59718778587606E-14 / Projection distortion parameter
# A_1_1   = 1.08369705855078E-07 / Projection distortion parameter
# A_1_2   = 1.39108425400024E-10 / Projection distortion parameter
# A_1_3   = 2.11999317938438E-14 / Projection distortion parameter
# A_2_0   = -5.9458574884441E-08 / Projection distortion parameter
# A_2_1   = 4.33426358061009E-10 / Projection distortion parameter
# A_2_2   = 1.35189170571019E-13 / Projection distortion parameter
# A_3_0   = -2.08220134210529E-10 / Projection distortion parameter
# A_3_1   = -1.08883792102563E-13 / Projection distortion parameter
# A_4_0   = 1.38761265311086E-13 / Projection distortion parameter
# A_DMAX  =     1.44644116295811 / Projection distortion parameter
# B_ORDER =                    4 / Distortion order for B
# B_0_2   = -9.05026964701004E-07 / Projection distortion parameter
# B_0_3   = -2.37895042883553E-10 / Projection distortion parameter
# B_0_4   = -2.79492116073048E-14 / Projection distortion parameter
# B_1_1   = -5.68043446827801E-08 / Projection distortion parameter
# B_1_2   = -1.35855168637522E-11 / Projection distortion parameter
# B_1_3   = -1.0337325389413E-15 / Projection distortion parameter
# B_2_0   = 1.17372776850073E-08 / Projection distortion parameter
# B_2_1   = -9.92433133809934E-11 / Projection distortion parameter
# B_2_2   = -2.89006454400011E-14 / Projection distortion parameter
# B_3_0   = -1.81344878069291E-10 / Projection distortion parameter
# B_3_1   = -7.60259332493222E-14 / Projection distortion parameter
# B_4_0   = -1.11217389686385E-13 / Projection distortion parameter
# B_DMAX  =     6.46327544106108 / Projection distortion parameter
# AP_ORDER=                    4 / Distortion order for AP
# AP_0_1  = 7.98987622453168E-07 / Projection distortion parameter
# AP_0_2  = -3.74614748175158E-08 / Projection distortion parameter
# AP_0_3  = -9.12476939309384E-11 / Projection distortion parameter
# AP_0_4  = -1.6048047254377E-14 / Projection distortion parameter
# AP_1_0  = -9.78753448092653E-07 / Projection distortion parameter
# AP_1_1  = -1.09226310538986E-07 / Projection distortion parameter
# AP_1_2  = -1.38723799583628E-10 / Projection distortion parameter
# AP_1_3  = -2.10754871268013E-14 / Projection distortion parameter
# AP_2_0  = 6.12173160249242E-08 / Projection distortion parameter
# AP_2_1  = -4.35277710201341E-10 / Projection distortion parameter
# AP_2_2  = -1.35646890438259E-13 / Projection distortion parameter
# AP_3_0  = 2.09215084242082E-10 / Projection distortion parameter
# AP_3_1  = 1.09581129768572E-13 / Projection distortion parameter
# AP_4_0  = -1.4054387202761E-13 / Projection distortion parameter
# BP_ORDER=                    4 / Distortion order for BP
# BP_0_1  = -7.53214490385127E-07 / Projection distortion parameter
# BP_0_2  = 9.07951658363086E-07 / Projection distortion parameter
# BP_0_3  =  2.4068064062164E-10 / Projection distortion parameter
# BP_0_4  = 2.84063964322882E-14 / Projection distortion parameter
# BP_1_0  = -3.20744825517069E-07 / Projection distortion parameter
# BP_1_1  = 5.73593059645703E-08 / Projection distortion parameter
# BP_1_2  = 1.37704511345533E-11 / Projection distortion parameter
# BP_1_3  = 1.02806986836748E-15 / Projection distortion parameter
# BP_2_0  = -1.54100257762635E-08 / Projection distortion parameter
# BP_2_1  = 9.95597869643947E-11 / Projection distortion parameter
# BP_2_2  = 2.90770668848743E-14 / Projection distortion parameter
# BP_3_0  = 1.82026514680915E-10 / Projection distortion parameter
# BP_3_1  = 7.57385989612067E-14 / Projection distortion parameter
# BP_4_0  = 1.13455176754232E-13 / Projection distortion parameter
#
#           / DATA FLOW
#
# ORIGNAME= '/data/PTF_default_58510.fits' / Filename as written by the camera
# FILENAME= 'PTF200909214162_2_o_58510.fits' / Filename of delivered camera image
# PROCORIG= 'IPAC-PTF pipelines' / Processing origin
# PROCDATE= 'Tue Feb 14 23:57:56 2012' / Processing date/time (Pacific time)
# PTFVERSN=                   5. / Version of PTFSCIENCEPIPELINE program
# PMASKPTH= '/ptf/pos/archive/fallbackcal/pmasks/' / Pathname of pixel mask
# PMASKFIL= 'bpm_2009060s_c09.v2.fits' / Filename of pixel mask
# SFLATPTH= '/ptf/pos/sbx2/2009/09/21/f2/c9/cal/p4/cId75244/' / Pathname of super
# SFLATFIL= 'PTF_200909210000_i_s_flat_t120000_u000075244_f02_p000000_c09.fits'
# SBIASPTH= '/ptf/pos/sbx2/2009/09/21/f2/c9/cal/p1/cId75182/' / Pathname of super
# SBIASFIL= 'PTF_200909210000_i_s_bias_t120000_u000075182_f00_p000000_c09.fits'
# DBNID   =                  207 / Database night ID
# DBEXPID =                40952 / Database exposure ID
# DBRID   =              3417124 / Database raw-image ID
# DBPID   =             11929627 / Database processed-image ID
# DBFID   =                    2 / Database filter ID
# DBPIID  =                    1 / Database P.I. ID
# DBPRID  =                    4 / Database project ID
# DBFIELD =                40952 / Database field ID
# DBSVID  =                   49 / Database software-version ID
# DBCVID  =                   55 / Database config-data-file ID
# INFOBITS=                    0 / Database infobits (2^2 and 2^3 excluded)

# %%
image_data = hdu_list[0].data
hdu_list.close()

# %%
minpx = np.mean(image_data)-2*np.std(image_data)
maxpx = np.mean(image_data)+2*np.std(image_data)
plt.figure(figsize=(10,10))
plt.imshow(image_data, origin='lower', cmap='gray', vmin=minpx, vmax=maxpx)
plt.colorbar()

# %%
catalog_url = metadata_page + hdu_header['SCAMPPTH'] + hdu_header['SCAMPFIL']
print(catalog_url)
#image_file = download_file(image_url)
# Out:
# http://irsa.ipac.caltech.edu/ibe/search/ptf/images/level1?POS={},{}/ptf/pos/archive/fallbackcal/scamp/9/PTF_201011182981_c_e_uca3_t070920_u002761444_f02_p100111_c09.fits
